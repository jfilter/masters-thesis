# %%
import pandas as pd
from pathlib import Path

# %%
PATH = Path('/mnt/data/group07/johannes/ynacc_proc/clean_split/articles_fixed_2.csv')
URL_PATH = Path('/mnt/data/group07/johannes/ynacc_proc/clean_split/urls.csv')

# %%
df = pd.read_csv(PATH)

# %%
df
# Out:
#      Unnamed: 0                                                url  \
# 0             0  http://www.elle.com/culture/celebrities/news/a...
# 1             1  http://www.cosmopolitan.com/lifestyle/news/a56...
# 2             2  http://www.cosmopolitan.com/health-fitness/new...
# 3             3  http://www.insideedition.com/headlines/15888-e...
# 4             4  http://www.ozy.com/good-sht/the-dirtiest-socce...
# 5             5  http://www.womansday.com/health-fitness/a54485...
# 6             6  http://www.cosmopolitan.com/style-beauty/fashi...
# 7             7  http://www.vibe.com/2016/04/texas-cop-caught-b...
# 8             8  http://hellogiggles.com/trans-woman-selfie-bat...
# 9             9  http://mashable.com/2016/04/16/waitress-tip-bi...
# 10           10  http://mashable.com/2016/04/08/capybaras-hide-...
# 11           11  http://www.etonline.com/tv/186166_khloe_kardas...
# 12           12  http://www.golf.com/tour-and-news/7-golf-recor...
# ...

# %%
urls = pd.read_csv(URL_PATH, header=None)

# %%
urls
# Out:
#                                                      0
# 0    http://www.cosmopolitan.com/lifestyle/news/a56...
# 1    http://mic.com/articles/142323/this-old-navy-a...
# 2    http://mic.com/articles/141141/patrick-brown-j...
# 3    http://www.cosmopolitan.com/health-fitness/new...
# 4    http://www.insideedition.com/headlines/15888-e...
# 5    http://www.ozy.com/good-sht/the-dirtiest-socce...
# 6    http://www.womansday.com/health-fitness/a54485...
# 7    http://www.cosmopolitan.com/style-beauty/fashi...
# 8    http://www.vibe.com/2016/04/texas-cop-caught-b...
# 9    http://hellogiggles.com/trans-woman-selfie-bat...
# 10   http://mashable.com/2016/04/16/waitress-tip-bi...
# 11   http://mic.com/articles/139828/do-aliens-exist...
# 12   http://www.insideedition.com/headlines/15808-m...
# 13   http://mic.com/articles/142537/trans-woman-att...
# 14   http://mashable.com/2016/04/08/capybaras-hide-...
# 15   http://mic.com/articles/140998/this-woman-s-st...
# ...

# %%
new_urls = list(df['url'])

# %%
len(new_urls)
# Out:
# 675

# %%
len(set(new_urls))
# Out:
# 671

# %%
orig_urls = list(urls[0])

# %%
len(orig_urls)
# Out:
# 679

# %%
len(set(orig_urls))
# Out:
# 679

# %%
set(orig_urls).difference(set(new_urls))
# Out:
# {'http://thehollywoodrep2197-yahoopartner.tumblr.com/post/142365703514/keshas-hate-crime-claims-against-dr-luke',
#  'http://thehollywoodrep2197-yahoopartner.tumblr.com/post/142755703259/ringo-starr-cancels-north-carolina-concert-over',
#  'http://thehollywoodrep2197-yahoopartner.tumblr.com/post/143114189934/julia-louis-dreyfus-reveals-awkward-fan-letter',
#  'http://thehollywoodrep2197-yahoopartner.tumblr.com/post/143171958039/legendary-artist-prince-found-dead-at-57',
#  'http://thehollywoodrep2197-yahoopartner.tumblr.com/post/143373116824/garry-shandlings-a-list-memorial-penis-jokes',
#  'http://variety-yahoopartner.tumblr.com/post/142358908132/merle-haggard-country-music-legend-dies-at-79',
#  'http://variety-yahoopartner.tumblr.com/post/142996692867/nina-review-controversial-biopic-is-one-bum',
#  'http://variety-yahoopartner.tumblr.com/post/143018920742/captain-america-civil-war-eyes-massive-175'}

# %%
set(new_urls).difference(set(orig_urls))
# Out:
# set()

# %%
df_f = df[['url', 'text', 'title', 'publish_date']]

# %%
df_f
# Out:
#                                                    url  \
# 0    http://www.elle.com/culture/celebrities/news/a...
# 1    http://www.cosmopolitan.com/lifestyle/news/a56...
# 2    http://www.cosmopolitan.com/health-fitness/new...
# 3    http://www.insideedition.com/headlines/15888-e...
# 4    http://www.ozy.com/good-sht/the-dirtiest-socce...
# 5    http://www.womansday.com/health-fitness/a54485...
# 6    http://www.cosmopolitan.com/style-beauty/fashi...
# 7    http://www.vibe.com/2016/04/texas-cop-caught-b...
# 8    http://hellogiggles.com/trans-woman-selfie-bat...
# 9    http://mashable.com/2016/04/16/waitress-tip-bi...
# 10   http://mashable.com/2016/04/08/capybaras-hide-...
# 11   http://www.etonline.com/tv/186166_khloe_kardas...
# 12   http://www.golf.com/tour-and-news/7-golf-recor...
# 13   http://www.etonline.com/news/186980_dax_shepar...
# 14   http://www.xojane.com/it-happened-to-me/rapist...
# 15   http://www.goodhousekeeping.com/life/parenting...
# ...

# %%
df_f = df_f.drop_duplicates()

# %%
df_f
# Out:
#                                                    url  \
# 0    http://www.elle.com/culture/celebrities/news/a...
# 1    http://www.cosmopolitan.com/lifestyle/news/a56...
# 2    http://www.cosmopolitan.com/health-fitness/new...
# 3    http://www.insideedition.com/headlines/15888-e...
# 4    http://www.ozy.com/good-sht/the-dirtiest-socce...
# 5    http://www.womansday.com/health-fitness/a54485...
# 6    http://www.cosmopolitan.com/style-beauty/fashi...
# 7    http://www.vibe.com/2016/04/texas-cop-caught-b...
# 8    http://hellogiggles.com/trans-woman-selfie-bat...
# 9    http://mashable.com/2016/04/16/waitress-tip-bi...
# 10   http://mashable.com/2016/04/08/capybaras-hide-...
# 11   http://www.etonline.com/tv/186166_khloe_kardas...
# 12   http://www.golf.com/tour-and-news/7-golf-recor...
# 13   http://www.etonline.com/news/186980_dax_shepar...
# 14   http://www.xojane.com/it-happened-to-me/rapist...
# 15   http://www.goodhousekeeping.com/life/parenting...
# ...

# %%
df_f[df_f.duplicated(['url'], keep=False)]
# Out:
#                                                    url  \
# 0    http://www.elle.com/culture/celebrities/news/a...
# 352  http://time.com/4419503/nba-all-star-game-char...
# 379  http://time.com/4452330/millennials-republican...
# 398  http://www.elle.com/culture/celebrities/news/a...
# 597  http://time.com/money/4288430/cuba-beer-americ...
# 599  http://time.com/4419503/nba-all-star-game-char...
# 600  http://time.com/4452330/millennials-republican...
# 601  http://time.com/money/4288430/cuba-beer-americ...
#
#                                                   text  \
# 0    Celine Dion started off Jimmy Fallon's Tonight...
# 352  About Your Privacy on this Site\n\nWelcome! To...
# 379  About Your Privacy on this Site\n\nWelcome! To...
# 398  Celine Dion started off Jimmy Fallon's Tonight...
# 597  About Your Privacy on this Site\n\nWelcome! To...
# 599  The NBA announced Thursday that negotiations h...
# 600  A new poll finds a significant gap in young vo...
# ...

# %%
df_b = df_f[df_f.text.str.contains("About Your Privacy on this Site") == False]

# %%
df_b
# Out:
#                                                    url  \
# 0    http://www.elle.com/culture/celebrities/news/a...
# 1    http://www.cosmopolitan.com/lifestyle/news/a56...
# 2    http://www.cosmopolitan.com/health-fitness/new...
# 3    http://www.insideedition.com/headlines/15888-e...
# 4    http://www.ozy.com/good-sht/the-dirtiest-socce...
# 5    http://www.womansday.com/health-fitness/a54485...
# 6    http://www.cosmopolitan.com/style-beauty/fashi...
# 7    http://www.vibe.com/2016/04/texas-cop-caught-b...
# 8    http://hellogiggles.com/trans-woman-selfie-bat...
# 9    http://mashable.com/2016/04/16/waitress-tip-bi...
# 10   http://mashable.com/2016/04/08/capybaras-hide-...
# 11   http://www.etonline.com/tv/186166_khloe_kardas...
# 12   http://www.golf.com/tour-and-news/7-golf-recor...
# 13   http://www.etonline.com/news/186980_dax_shepar...
# 14   http://www.xojane.com/it-happened-to-me/rapist...
# 15   http://www.goodhousekeeping.com/life/parenting...
# ...

# %%
PATH_OUT = Path('/mnt/data/group07/johannes/ynacc_proc/clean_split/articles_fixed_3.csv')
df_b.to_csv(PATH_OUT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d5ae226c50dd> in <module>
#       1 PATH_OUT = Path('/mnt/data/group07/johannes/ynacc_proc/clean_split/articles_fixed_3.csv')
# ----> 2 df_b.to_csv(PATH_OUT)
#
# NameError: name 'df_b' is not defined

# %%
df_c = pd.read_csv(Path('~/data/ynacc_proc/articles/articles_fixed_3.csv'))

# %%
df_c = df_c.drop('Unnamed: 0', axis=1)

# %%
df_c
# Out:
#                                                    url  \
# 0    http://www.elle.com/culture/celebrities/news/a...
# 1    http://www.cosmopolitan.com/lifestyle/news/a56...
# 2    http://www.cosmopolitan.com/health-fitness/new...
# 3    http://www.insideedition.com/headlines/15888-e...
# 4    http://www.ozy.com/good-sht/the-dirtiest-socce...
# 5    http://www.womansday.com/health-fitness/a54485...
# 6    http://www.cosmopolitan.com/style-beauty/fashi...
# 7    http://www.vibe.com/2016/04/texas-cop-caught-b...
# 8    http://hellogiggles.com/trans-woman-selfie-bat...
# 9    http://mashable.com/2016/04/16/waitress-tip-bi...
# 10   http://mashable.com/2016/04/08/capybaras-hide-...
# 11   http://www.etonline.com/tv/186166_khloe_kardas...
# 12   http://www.golf.com/tour-and-news/7-golf-recor...
# 13   http://www.etonline.com/news/186980_dax_shepar...
# 14   http://www.xojane.com/it-happened-to-me/rapist...
# 15   http://www.goodhousekeeping.com/life/parenting...
# ...

# %%
df_c[df_c.duplicated(subset=['url'], keep=False)]
# Out:
#                                                    url  \
# 0    http://www.elle.com/culture/celebrities/news/a...
# 396  http://www.elle.com/culture/celebrities/news/a...
#
#                                                   text  \
# 0    Celine Dion started off Jimmy Fallon's Tonight...
# 396  Celine Dion started off Jimmy Fallon's Tonight...
#
#                                                  title         publish_date
# 0    Celine Dion Doing This Rihanna Impression Is E...                  NaN
# 396  Celine Dion Doing This Rihanna Impression Is E...  2016-07-22 11:50:00

# %%
df_c = df_c.drop([0])

# %%
df_c[df_c.duplicated(subset=['url'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [url, text, title, publish_date]
# Index: []

# %%
df_c.to_csv(Path('~/data/ynacc_proc/articles/articles_fixed_4.csv'))
