# %%
import pandas as pd
from pathlib import Path

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199

# %%
df = pd.read_csv('~/data/ynacc_proc/replicate/split/train.csv')

# %%
df['text'].tolist()
# Out:
# ["Yes..because too many houses in EU look like the original Disney Hunted House so it didn't look scary enough. Bates Motel looks more American and that notion alone scares everyone.",
#  'These things happen , Every job has its dangers.',
#  'Sad to hear such a bad thing. Very dangerous job working on electricity. One questions though, why did they use a picture the Bates house from Psycho, on a Disney story? Or is that what the Paris Haunted Mansion/Phantom Manor looks like?',
#  'THANK YOU!!!!!!!!!!!!!!!! So annoying.. journalism today is questionable... @USERNAME',
#  "lol i thought it's my computer",
#  "It's on the Cosmopolitan article you dolt.",
#  'You have to click on the link to go to Cosmo. Yahoo has been terrible about this lately.',
#  "Is it just my computer or is there not a single picture of her post-baby belly on this article? I didn't even see one on her Twitter account. Good grief.",
#  'why is she sick --American laws are sick --16 is not a kid',
# ...

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# 5              5             5
# 6              6             6
# 7              7             7
# 8              8             8
# 9              9             9
# 10            10            10
# 11            11            11
# 12            12            12
# 13            13            13
# 14            14            14
# 15            15            15
# 16            16            16
# 17            17            17
# 18            18            18
# 19            19            19
# 20            20            20
# 21            21            21
# 22            22            22
# 23            23            23
# 24            24            24
# 25            25            25
# 26            26            26
# 27            27            27
# 28            28            28
# ...

# %%
df[df['text'].str.len() < 80][['text', 'commentid']]
# Out:
#                                                                                  text  \
# 1     These things happen , Every job has its dangers.
# 4     lol i thought it's my computer
# 5     It's on the Cosmopolitan article you dolt.
# 8     why is she sick --American laws are sick --16 is not a kid
# 11    She was a good Christian!?!!
# 12    Hot for Teacher. It's as American as Apple Pie.
# 14    I have always heard,if there is grass on the field,play ball
# 17    l
# 18    Societal and family pressures...she'll be enlightened later...
# 19    Would you feel the same way if it were your 16 year old daughter?
# 22    Youmeanupmyass?
# 23    Why didn't they have these teachers when i was in school.
# 24    russell, c'mon, you're better than that.
# 27    No he's not. probably muslum or morman.
# 28    Let's not forget that she might also have a disease.
# 31    Upmyassisthat what you're saying?
# 34    Yah I agreed.
# 35    Hey, where did Mike go?
# ...

# %%
df.iloc[1975]
# Out:
# Unnamed: 0           1975
# Unnamed: 0.1         1975
# url                  http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
# ...

# %%
df[df['sdid'] == 76542].sort_values('commentindex')
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 1982  1982        1982
# 1974  1974        1974
# 1975  1975        1975
# 1976  1976        1976
# 1977  1977        1977
# 1978  1978        1978
# 1979  1979        1979
# 1980  1980        1980
# 1981  1981        1981
#
#                                                                                       url  \
# 1982  http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
# 1974  http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
# 1975  http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
# 1976  http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
# 1977  http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
# 1978  http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
# ...

# %%
df.iloc[7877]
# Out:
# Unnamed: 0                                                        7877
# Unnamed: 0.1                                                      7877
# url                  http://thehollywoodrep2197-yahoopartner.tumblr...
# article_text                                                       NaN
# title                                                              NaN
# publish_date                                                       NaN
# commentid            0000fb000000000000000000000000-fe463bff-88f6-4...
# clcontroversial                                                      0
# clmean                                                               0
# clinformative                                                        1
# cldisagreement                                                       1
# clagreement                                                          0
# clsentiment                                                          1
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'url', 'article_text', 'title',
#        'publish_date', 'commentid', 'clcontroversial', 'clmean',
#        'clinformative', 'cldisagreement', 'clagreement', 'clsentiment',
#        'clpersuasive', 'claudience', 'index', 'sdid', 'commentindex',
#        'headline', 'guid', 'timestamp', 'thumbs-up', 'thumbs-down', 'text',
#        'parentid', 'constructiveclass', 'sd_agreement', 'sd_type', 'sentiment',
#        'tone', 'commentagreement', 'topic', 'intendedaudience',
#        'persuasiveness', 'text_proc', 'cltopic'],
#       dtype='object')

# %%
df[df['sdid'] == 21030].sort_values('commentindex')['text'].tolist()
# Out:
# ["So will she be charged for perjury? Fabricating and accusing some one of a terrible crime? I mean at the very least make her foot the bill for this circus? Sadly none of this will happen taxpayers will pay for this divas attempt to illegal nullify her contract. The message we send is don't worry if you lie under oath, or waste time,money,resources that could be going to actual victims. No don't worry in fact try your luck, because there is literally no repercussions for your actions.",
#  "What she said is true, and he apparently did rape her, but the reason it can't be tried is because it was too long ago.  Yes, if you can make it 7 years without being accused, rape is no longer a crime.",
#  'Did you read a different article?  What are you talking about?',
#  'Why would she be charged with perjury? The judge is not saying that Kesha lied, only that one crime Kesha claimed happened is too old and the others the judge has no jurisdiction over.',
# ...

# %%
df.iloc[39]
# Out:
# Unnamed: 0                                                          39
# Unnamed: 0.1                                                        39
# url                  http://www.insideedition.com/headlines/15888-e...
# article_text         Headlines Teacher Allegedly Had Sex With Stude...
# title                Teacher Allegedly Had Sex With Student On Nigh...
# publish_date                                                       NaN
# commentid            00007b000000000000000000000000-e6665078-55cb-4...
# clcontroversial                                                      0
# clmean                                                               0
# clinformative                                                        0
# cldisagreement                                                       1
# clagreement                                                          0
# clsentiment                                                          1
# ...

# %%
df[df['sdid'] == 68273].sort_values('commentindex')['text'].tolist()
# Out:
# ['Her husband is staying with her too. Cheating is one thing, but obviously this lady is sick. He needs to leave her. I could see maybe trying to work it out if it were just the cheating alone and one time thing, but she is disgusting sleeping with a teenage student. Also factor in that she was cheating on him while engaged and newlyweds. A stray down the road can be forgiven, but she was doing this from the beginning. Hopefully he wises up and leaves her.',
#  'why is she sick --American laws are sick --16 is not a kid',
#  'Dude if your fiance is cheating on you WHILE YOU ARE AT YOUR BACHELOR PARTY.... RUN and never look back.',
#  "russell, c'mon, you're better than that.",
#  "No he's not. probably muslum or morman.",
#  "Jesus Christ have a little compassion, teen boys are #$%$ &devious.she's a twenty-something naive& #$%$.Then he rats her out. Typical slug. it's unfair it's not as bad as it sounds.",
#  'Why leave ...he has a hall pass for life']

# %%
BASE_PATH = Path('/mnt/data/datasets/ydata-ynacc-v1_0')

# %%
dfo = pd.read_table(BASE_PATH/'ydata-ynacc-v1_0_expert_annotations.tsv')

# %%
dfo.columns
# Out:
# Index(['sdid', 'commentindex', 'headline', 'url', 'guid', 'commentid',
#        'timestamp', 'thumbs-up', 'thumbs-down', 'text', 'parentid',
#        'constructiveclass', 'sd_agreement', 'sd_type', 'sentiment', 'tone',
#        'commentagreement', 'topic', 'intendedaudience', 'persuasiveness'],
#       dtype='object')

# %%
dfo[dfo['commentid'] == '00003n000000000000000000000000-f6ddc816-241b-48ab-8aa6-1e3bc2701f30']
# Out:
#         sdid  commentindex  \
# 4896   76542  2
# 13717  76542  2
# 13726  76542  2
#
#                                                                                 headline  \
# 4896   Teen Allegedly Snapchats Her Entire Debilitating Car Crash Using the Speed Filter
# 13717  Teen Allegedly Snapchats Her Entire Debilitating Car Crash Using the Speed Filter
# 13726  Teen Allegedly Snapchats Her Entire Debilitating Car Crash Using the Speed Filter
#
#                                                                                        url  \
# 4896   http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
# 13717  http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
# 13726  http://www.cosmopolitan.com/lifestyle/news/a57643/christal-mcgee-snapchat-accident/
#
#                        guid  \
# 4896   r9DJjyLLPwT28GN2kMdT
# 13717  r9DJjyLLPwT28GN2kMdT
# 13726  r9DJjyLLPwT28GN2kMdT
#
# ...
