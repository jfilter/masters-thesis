# %%
import json

import pandas as pd

from pathlib import Path

from fastai.text.transform import BaseTokenizer, Tokenizer, Vocab
from fastai.text.data import TextLMDataBunch
import swifter
import fastai

import numpy as np

from bpemb import BPEmb

# %%
fastai.__version__
# Out:
# '1.0.42'

# %%
bpemb_de = BPEmb(lang="de", vs=25000, dim=300)

# %%
bpemb_de = BPEmb(lang="de", vs=25000, dim=300)
itos = dict(enumerate(bpemb_de.words + ['xxpad']))
voc = Vocab(itos)

# %%
input_p = '/mnt/data/group07/johannes/germanlm/proc/final_merged'
# input_p = '/mnt/data/group07/johannes/germanlm/proc/final_lemma'

# %%
tmp = []
for p in list(Path(input_p).glob('*.txt'))[:-3]:
    tmp.append(pd.read_table(p, header=None))
df_train = pd.concat(tmp)
del tmp

# %%
df_train[0] = df_train[0].swifter.apply(lambda x: bpemb_de.encode_ids_with_bos_eos(x))
# Out:
# Pandas Apply: 100%|██████████| 2978665/2978665 [1:58:27<00:00, 419.10it/s]

# %%
df_train.to_csv('/mnt/data/group07/johannes/germanlm/proc/tokenized_lemma/df_train.csv')

# %%
del df_train

# %%
tmp = []
for p in list(Path(input_p).glob('*.txt'))[-3:]:
    tmp.append(pd.read_table(p, header=None))
df_val = pd.concat(tmp)
del tmp

# %%
df_val[0] = df_val[0].swifter.apply(lambda x: bpemb_de.encode_ids_with_bos_eos(x))
# Out:
# Pandas Apply: 100%|██████████| 299992/299992 [11:56<00:00, 418.77it/s]

# %%
df_val.to_csv('/mnt/data/group07/johannes/germanlm/proc/tokenized_lemma/df_val.csv')

# %%
class BpembTokenizer(BaseTokenizer):
    def tokenizer(self, t):
        return bpemb_de.encode(t)
#         res = []
#         doc = nlp(t)
#         for s in docs.sents:
#             res += bpemb_de.encode(s)
#         return res

# %%
# class BpembTokenizer(BaseTokenizer):
#     def tokenizer(self, t):
#         res = []
#         tokenizer = somajo.Tokenizer(split_camel_case=True, token_classes=False, extra_info=False)
#         tokens = tokenizer.tokenize(str(t))
        
#         sentence_splitter = somajo.SentenceSplitter(is_tuple=False)
#         sentences = sentence_splitter.split(tokens)

#         for s in sentences:
#             print(s)
#             res += bpemb_de.encode(' '.join(s))
#         return res

# %%
# tok = Tokenizer(tok_func=BpembTokenizer)

# %%
train_ids = pd.read_csv('/mnt/data/group07/johannes/germanlm/proc/tokenized_lemma/df_train.csv')

# %%
val_ids = pd.read_csv('/mnt/data/group07/johannes/germanlm/proc/tokenized_lemma/df_val.csv')

# %%
val_ids = np.array([np.array(json.loads(x[0])) for x in val_ids[['0']].values])
train_ids = np.array([np.array(json.loads(x[0])) for x in train_ids[['0']].values])

# %%
# itos = dict(enumerate(bpemb_de.words))

# %%
# itos
# Out:
# {0: '<unk>',
#  1: '<s>',
#  2: '</s>',
#  3: 'er',
#  4: 'en',
#  5: '▁d',
#  6: 'ch',
#  7: 'in',
#  8: '00',
#  9: 'ie',
#  10: '▁s',
#  11: 'un',
#  12: '▁a',
#  13: 'te',
#  14: 'ei',
#  15: 'an',
#  16: '▁b',
#  17: 'es',
#  18: 'is',
#  19: '▁w',
#  20: 'on',
#  21: '▁00',
#  22: '▁v',
#  23: 'ein',
#  24: 'or',
#  25: '▁m',
#  26: '▁der',
#  27: '▁g',
#  28: '▁k',
#  29: '▁un',
#  30: 'ar',
#  31: '▁die',
#  32: 'ur',
#  33: '▁f',
#  34: 'st',
#  35: "''",
#  36: '▁0000',
#  37: 'al',
#  38: 'it',
#  39: '▁in',
#  40: 'ich',
#  41: '▁z',
#  42: 'el',
#  43: '▁und',
#  44: '▁h',
#  45: '▁n',
#  46: '▁ein',
#  47: 'at',
#  48: 'us',
#  49: 'ung',
#  50: 'em',
#  51: 'as',
#  52: '▁p',
#  53: 'ten',
#  54: 'sch',
#  55: '▁l',
#  56: 'ter',
#  57: 'de',
#  58: 'hr',
#  59: '▁(',
#  60: '▁er',
#  61: '▁r',
#  62: 'ig',
#  63: 'isch',
#  64: '▁i',
#  65: 'ol',
#  66: 'il',
#  67: '▁*',
#  68: 'der',
#  69: 'den',
#  70: '▁au',
#  71: '▁j',
#  72: '▁t',
#  73: 'am',
#  74: 'ber',
#  75: 'au',
#  76: '▁von',
#  77: 'ge',
#  78: "▁''",
#  79: '▁an',
#  80: 'ach',
#  81: '▁ver',
#  82: 'et',
#  83: 'um',
#  84: 'gen',
#  85: '▁al',
#  86: '▁st',
#  87: 'and',
#  88: '▁im',
#  89: 'lich',
#  90: '▁mit',
#  91: '▁den',
#  92: 'ier',
#  93: '▁des',
#  94: 'om',
#  95: 'eit',
#  96: 'ion',
#  97: '▁sch',
#  98: '▁ge',
#  99: '▁das',
#  100: 'ist',
#  101: 'ck',
#  102: 'le',
#  103: '▁o',
#  104: 'ra',
#  105: 'ut',
#  106: 'ür',
#  107: 'ir',
#  108: 'ent',
#  109: '▁auf',
#  110: 'ro',
#  111: 'ate',
#  112: '▁be',
#  113: 're',
#  114: '▁zu',
#  115: 'ann',
#  116: 'rei',
#  117: '▁wur',
#  118: 'ik',
#  119: 'ben',
#  120: '0000',
#  121: 'ft',
#  122: 'ischen',
#  123: '▁aus',
#  124: 'ahr',
#  125: '▁c',
#  126: '▁0',
#  127: 'orie',
#  128: 'ateg',
#  129: '▁kateg',
#  130: '▁kategorie',
#  131: '▁dem',
#  132: 'se',
#  133: 'ste',
#  134: 'sen',
#  135: '▁als',
#  136: 'kt',
#  137: '▁für',
#  138: 'ah',
#  139: '▁e',
#  140: 'iel',
#  141: '▁wurde',
#  142: '▁ist',
#  143: 'ien',
#  144: 'sp',
#  145: 'ad',
#  146: '▁nach',
#  147: 'ver',
#  148: '▁bei',
#  149: '▁eine',
#  150: 'ff',
#  151: '▁de',
#  152: '▁sp',
#  153: '▁war',
#  154: 'icht',
#  155: 'ger',
#  156: 'än',
#  157: 'wei',
#  158: '▁sein',
#  159: 'est',
#  160: '▁sich',
#  161: 'he',
#  162: '▁am',
#  163: '▁jahr',
#  164: 'la',
#  165: 'über',
#  166: '▁re',
#  167: 'men',
#  168: 'os',
#  169: 'ab',
#  170: 'ul',
#  171: 'ne',
#  172: '▁00.',
#  173: 'scha',
#  174: 'eich',
#  175: 'rie',
#  176: '▁so',
#  177: 'ot',
#  178: '▁sie',
#  179: 'ort',
#  180: 'och',
#  181: '▁ab',
#  182: 'ün',
#  183: 'ation',
#  184: 'ler',
#  185: '▁über',
#  186: 'ische',
#  187: '▁unter',
#  188: 'tel',
#  189: 'ges',
#  190: '▁vor',
#  191: 'ru',
#  192: 'ri',
#  193: 'ing',
#  194: '),',
#  195: 'und',
#  196: 'aus',
#  197: 'ern',
#  198: 'eu',
#  199: 'hn',
#  200: '▁auch',
#  201: 'ind',
#  202: 'urch',
#  203: '▁000',
#  204: 'ungen',
#  205: 'utsch',
#  206: '▁bis',
#  207: 'ang',
#  208: 'ehr',
#  209: 'op',
#  210: 'len',
#  211: '▁um',
#  212: 'ster',
#  213: 'schaft',
#  214: 'im',
#  215: '▁wer',
#  216: 'ag',
#  217: '▁fr',
#  218: '▁durch',
#  219: 'lie',
#  220: '▁ar',
#  221: 'teil',
#  222: 'etz',
#  223: '▁ber',
#  224: 'ser',
#  225: '▁ges',
#  226: '▁bes',
#  227: 'ät',
#  228: 'ed',
#  229: '▁ent',
#  230: '▁„',
#  231: 'ör',
#  232: 'ungs',
#  233: 'chen',
#  234: '▁es',
#  235: '▁wir',
#  236: 'sten',
#  237: 'og',
#  238: 'all',
#  239: 'hen',
#  240: '▁zur',
#  241: 'be',
#  242: 'igen',
#  243: 'iv',
#  244: '▁einer',
#  245: '▁ch',
#  246: '▁gr',
#  247: '▁(0000',
#  248: '▁zum',
#  249: '▁wie',
#  250: '▁deutsch',
#  251: '▁0.',
#  252: 'ap',
#  253: 'geb',
#  254: 'ic',
#  255: 'cht',
#  256: '▁pro',
#  257: 'är',
#  258: '000',
#  259: 'gel',
#  260: 'end',
#  261: '▁wei',
#  262: 'gr',
#  263: 'ischer',
#  264: 'her',
#  265: 'wer',
#  266: '▁ihr',
#  267: '▁kon',
#  268: 'land',
#  269: 'anz',
#  270: '▁werden',
#  271: 'nen',
#  272: '▁–',
#  273: 'ige',
#  274: 'rä',
#  275: '▁nicht',
#  276: 'hal',
#  277: '▁her',
#  278: '▁br',
#  279: 'art',
#  280: '▁le',
#  281: 'lin',
#  282: 'ord',
#  283: 'mer',
#  284: '▁hat',
#  285: 'che',
#  286: '▁wird',
#  287: 'bur',
#  288: 'gt',
#  289: 'adt',
#  290: '▁sind',
#  291: 'hl',
#  292: 'lichen',
#  293: 'itz',
#  294: 'elt',
#  295: 'tet',
#  296: 'ück',
#  297: '–0000',
#  298: 'ühr',
#  299: '▁einem',
#  300: 'pp',
#  301: 'ell',
#  302: '▁0000,',
#  303: '▁oder',
#  304: '▁zwei',
#  305: '▁se',
#  306: "'',",
#  307: 'auf',
#  308: 'od',
#  309: 'ia',
#  310: 'ön',
#  311: '▁0000:',
#  312: 'emein',
#  313: 'iert',
#  314: 'qu',
#  315: ').',
#  316: '▁en',
#  317: '▁ma',
#  318: 'det',
#  319: 'id',
#  320: 'ho',
#  321: 'ant',
#  322: 'iz',
#  323: 'uch',
#  324: 'pf',
#  325: 'ner',
#  326: '▁da',
#  327: '▁einen',
#  328: '▁kl',
#  329: 'ass',
#  330: '▁ne',
#  331: 'ud',
#  332: 'ank',
#  333: '▁zw',
#  334: '▁mar',
#  335: 'uss',
#  336: 'ers',
#  337: 'atz',
#  338: 'oll',
#  339: 'stel',
#  340: '▁land',
#  341: 'br',
#  342: 'bl',
#  343: 'reich',
#  344: 'liche',
#  345: 'pt',
#  346: 'ard',
#  347: 'ak',
#  348: '▁is',
#  349: 'burg',
#  350: 'ess',
#  351: '▁neu',
#  352: 'mann',
#  353: 'lt',
#  354: 'ug',
#  355: 'me',
#  356: '-0',
#  357: 'dert',
#  358: '▁wurden',
#  359: "''.",
#  360: 'wie',
#  361: 'ill',
#  362: 'ähr',
#  363: '▁kom',
#  364: '▁gro',
#  365: 'fl',
#  366: '▁fl',
#  367: 'ßen',
#  368: 'alt',
#  369: '▁dass',
#  370: '▁the',
#  371: 'ob',
#  372: 'ht',
#  373: '▁gen',
#  374: 'orm',
#  375: 'ok',
#  376: 'berg',
#  377: 'ick',
#  378: 'tern',
#  379: '▁lie',
#  380: 'wa',
#  381: '-0000',
#  382: 'spiel',
#  383: 'lung',
#  384: 'bau',
#  385: 'we',
#  386: 'fen',
#  387: 'oren',
#  388: '▁ei',
#  389: '▁dar',
#  390: 'sk',
#  391: 'ust',
#  392: '▁stadt',
#  393: 'rich',
#  394: '▁gegen',
#  395: '▁(0000–0000',
#  396: 'ierte',
#  397: '▁zeit',
#  398: 'ahl',
#  399: '▁te',
#  400: '▁teil',
#  401: 'enn',
#  402: '▁ste',
#  403: 'ahn',
#  404: '▁ander',
#  405: '▁gew',
#  406: 'sel',
#  407: ".''",
#  408: 'ow',
#  409: 'fol',
#  410: '▁gesch',
#  411: 'ekt',
#  412: 'rit',
#  413: '▁jo',
#  414: '▁(*',
#  415: 'gl',
#  416: 'amm',
#  417: 'äu',
#  418: '▁gl',
#  419: 'arb',
#  420: 'hei',
#  421: 'vers',
#  422: '▁kön',
#  423: 'reis',
#  424: 'ild',
#  425: '▁or',
#  426: '▁weiter',
#  427: 'fer',
#  428: '▁pol',
#  429: 'mal',
#  430: 'ov',
#  431: '▁mehr',
#  432: 'zen',
#  433: '▁et',
#  434: '▁mus',
#  435: 'ze',
#  436: '▁seit',
#  437: '▁vom',
#  438: 'att',
#  439: '▁nur',
#  440: 'ph',
#  441: 'pl',
#  442: 'bn',
#  443: '▁man',
#  444: 'eits',
#  445: '▁gemein',
#  446: 'ial',
#  447: 'ark',
#  448: '▁seine',
#  449: 'mit',
#  450: '▁ö',
#  451: 'ha',
#  452: 'hun',
#  453: 'rat',
#  454: 'ße',
#  455: '▁reg',
#  456: '▁bet',
#  457: '▁dies',
#  458: 'dem',
#  459: '▁of',
#  460: 'tes',
#  461: 'ational',
#  462: '▁noch',
#  463: '▁zus',
#  464: '▁spiel',
#  465: '▁0000.',
#  466: 'zeich',
#  467: 'per',
#  468: 'zeit',
#  469: '▁pl',
#  470: '▁gel',
#  471: 'ast',
#  472: 'ian',
#  473: 'führ',
#  474: '▁jahrhun',
#  475: '▁we',
#  476: 'eister',
#  477: '▁ha',
#  478: 'gesch',
#  479: '▁geb',
#  480: '▁isbn',
#  481: '▁ger',
#  482: 'ib',
#  483: '▁hin',
#  484: 'acht',
#  485: '▁zwischen',
#  486: 'haus',
#  487: 'ität',
#  488: 'atur',
#  489: 'zu',
#  490: '▁diese',
#  491: '▁bl',
#  492: '▁el',
#  493: 'üd',
#  494: '▁ro',
#  495: 'iger',
#  496: 'hör',
#  497: '▁jahrhundert',
#  498: 'arl',
#  499: '▁aber',
#  500: '▁hei',
#  501: '▁seiner',
#  502: 'aat',
#  503: '▁fol',
#  504: 'du',
#  505: 'ss',
#  506: 'pr',
#  507: 'öl',
#  508: 'min',
#  509: '▁sowie',
#  510: 'dern',
#  511: '▁ho',
#  512: 'glie',
#  513: '▁jahre',
#  514: '▁wieder',
#  515: 'hm',
#  516: 'kl',
#  517: 'ßer',
#  518: 'ilm',
#  519: 'amen',
#  520: 'io',
#  521: 'annt',
#  522: 'keit',
#  523: 'eiten',
#  524: 'bar',
#  525: 'lag',
#  526: 'ktion',
#  527: '▁bef',
#  528: '▁eines',
#  529: '▁dieser',
#  530: 'äl',
#  531: 'ammen',
#  532: 'wo',
#  533: '▁u',
#  534: 'ften',
#  535: '▁wo',
#  536: 'äch',
#  537: 'üt',
#  538: 'ay',
#  539: 'fr',
#  540: '▁all',
#  541: '▁beg',
#  542: 'iker',
#  543: 'los',
#  544: 'eter',
#  545: 'tem',
#  546: 'ans',
#  547: 'ichte',
#  548: 'utz',
#  549: 'ais',
#  550: '▁verb',
#  551: '▁schw',
#  552: 'ieren',
#  553: '▁us',
#  554: '▁welt',
#  555: 'fahr',
#  556: 'ts',
#  557: 'ffen',
#  558: 'tra',
#  559: '▁bau',
#  560: 'aupt',
#  561: 'ierung',
#  562: '▁**',
#  563: '▁arb',
#  564: 'änd',
#  565: 'mus',
#  566: 'fe',
#  567: 'schie',
#  568: 'net',
#  569: 'ce',
#  570: '▁-',
#  571: '▁hatte',
#  572: 'olog',
#  573: 'ikan',
#  574: 'ine',
#  575: 'hem',
#  576: 'ium',
#  577: 'orf',
#  578: 'nis',
#  579: '▁dam',
#  580: 'ivers',
#  581: '▁waren',
#  582: '▁verw',
#  583: 'spr',
#  584: '▁jed',
#  585: 'ke',
#  586: 'ym',
#  587: ',0',
#  588: '▁je',
#  589: 'rupp',
#  590: 'etzt',
#  591: 'ember',
#  592: 'ater',
#  593: '▁sel',
#  594: 'ken',
#  595: 'stand',
#  596: 'nah',
#  597: '▁pr',
#  598: 'ale',
#  599: 'ingen',
#  600: 'heit',
#  601: '▁drei',
#  602: '▁kir',
#  603: 'vor',
#  604: 'äter',
#  605: '▁par',
#  606: 'sb',
#  607: '▁was',
#  608: 'neh',
#  609: 'glich',
#  610: 'iet',
#  611: 'uß',
#  612: 'tete',
#  613: '▁ober',
#  614: 'fel',
#  615: 'issen',
#  616: 'pro',
#  617: '▁chr',
#  618: 'dr',
#  619: 'if',
#  620: 'ont',
#  621: 'eine',
#  622: 'ult',
#  623: '▁zusammen',
#  624: 'amer',
#  625: '▁he',
#  626: 'bst',
#  627: '▁ph',
#  628: '▁0000)',
#  629: '▁ex',
#  630: 'ks',
#  631: 'rieg',
#  632: '▁nie',
#  633: '▁erst',
#  634: '▁la',
#  635: '▁süd',
#  636: '▁jahren',
#  637: 'kom',
#  638: 'die',
#  639: '▁tr',
#  640: '▁best',
#  641: '▁ort',
#  642: '▁fin',
#  643: '▁qu',
#  644: 'aut',
#  645: 'eist',
#  646: '▁(0000–0000),',
#  647: 'ald',
#  648: '▁bo',
#  649: '▁ersten',
#  650: '▁staat',
#  651: 'undes',
#  652: '▁berlin',
#  653: '▁0000),',
#  654: '▁ur',
#  655: 'gte',
#  656: 'urop',
#  657: '▁son',
#  658: '▁jedoch',
#  659: '▁später',
#  660: '▁führ',
#  661: 'ließ',
#  662: 'hol',
#  663: 'weise',
#  664: '▁y',
#  665: "▁(''",
#  666: 'assen',
#  667: '▁verl',
#  668: '▁kur',
#  669: 'imm',
#  670: 'ub',
#  671: 'ma',
#  672: 'anden',
#  673: 'ip',
#  674: '▁eigen',
#  675: '-000',
#  676: '▁gra',
#  677: '▁bek',
#  678: 'ober',
#  679: 'ett',
#  680: 'rieb',
#  681: 'deutsch',
#  682: 'ition',
#  683: "'')",
#  684: '▁haupt',
#  685: 'orden',
#  686: 'cke',
#  687: '▁währ',
#  688: 'ball',
#  689: '▁kam',
#  690: 'ac',
#  691: 'enz',
#  692: 'elle',
#  693: 'pg',
#  694: 'iss',
#  695: 'ried',
#  696: 'entr',
#  697: 'form',
#  698: '▁hand',
#  699: '▁univers',
#  700: 'iele',
#  701: '▁gehör',
#  702: 'str',
#  703: '▁erfol',
#  704: '▁for',
#  705: '▁besch',
#  706: '▁(0000)',
#  707: '▁während',
#  708: 'wick',
#  709: '▁nord',
#  710: 'jpg',
#  711: 'ös',
#  712: '▁me',
#  713: '▁kann',
#  714: 'old',
#  715: '▁polit',
#  716: 'nung',
#  717: 'zer',
#  718: 'av',
#  719: '▁leben',
#  720: '▁fe',
#  721: 'gan',
#  722: '▁co',
#  723: 'stra',
#  724: 'auer',
#  725: 'ker',
#  726: 'reu',
#  727: '▁and',
#  728: '▁etwa',
#  729: 'unden',
#  730: 'lage',
#  731: 'aum',
#  732: '▁hö',
#  733: 'ive',
#  734: '▁deutschen',
#  735: '▁dort',
#  736: 'th',
#  737: 'aten',
#  738: '▁reich',
#  739: 'glied',
#  740: '▁tra',
#  741: 'arr',
#  742: '▁konn',
#  743: 'zeu',
#  744: '▁mün',
#  745: 'inn',
#  746: 'sterreich',
#  747: 'erson',
#  748: 'halten',
#  749: 'stadt',
#  750: 'bahn',
#  751: '▁stel',
#  752: '▁bundes',
#  753: 'hof',
#  754: 'olle',
#  755: '▁frei',
#  756: 'gest',
#  757: 'alen',
#  758: 'igkeit',
#  759: 'heim',
#  760: 'eute',
#  761: '▁ad',
#  762: 'stein',
#  763: 'ander',
#  764: '▁beim',
#  765: 'amil',
#  766: '▁stra',
#  767: 'meister',
#  768: 'grün',
#  769: '▁vier',
#  770: '▁ihre',
#  771: 'tschaft',
#  772: 'fall',
#  773: 'amt',
#  774: '▁könig',
#  775: '▁einz',
#  776: '▁franz',
#  777: '▁vers',
#  778: 'gemein',
#  779: 'pen',
#  780: 'als',
#  781: '▁deutscher',
#  782: '▁gemeinde',
#  783: 'tr',
#  784: 'öff',
#  785: '▁hier',
#  786: 'onder',
#  787: 'si',
#  788: '00.',
#  789: 'isten',
#  790: 'schen',
#  791: '▁aug',
#  792: '▁erste',
#  793: '▁mo',
#  794: 'äd',
#  795: 'ital',
#  796: '▁komm',
#  797: 'gang',
#  798: '▁gleich',
#  799: 'rift',
#  800: 'ähl',
#  801: '▁bel',
#  802: 'cken',
#  803: 'schaften',
#  804: 'iff',
#  805: 'ek',
#  806: 'ule',
#  807: '▁kr',
#  808: '▁frank',
#  809: '▁zurück',
#  810: '▁erh',
#  811: '▁heute',
#  812: 'yn',
#  813: '▁lei',
#  814: '▁verein',
#  815: '▁ben',
#  816: 'schl',
#  817: 'ielt',
#  818: 'ellen',
#  819: '▁eben',
#  820: 'our',
#  821: 'az',
#  822: '▁europ',
#  823: '▁film',
#  824: '▁ins',
#  825: 'gung',
#  826: 'igt',
#  827: '▁schl',
#  828: 'zw',
#  829: '▁jan',
#  830: 'ond',
#  831: '▁nieder',
#  832: 'els',
#  833: 'werk',
#  834: 'man',
#  835: 'kehr',
#  836: '▁th',
#  837: '▁grund',
#  838: 'the',
#  839: '▁groß',
#  840: 'unter',
#  841: '▁grö',
#  842: '▁men',
#  843: '▁spr',
#  844: '▁ant',
#  845: 'bert',
#  846: '▁ende',
#  847: '▁seinen',
#  848: 'ite',
#  849: 'chn',
#  850: '▁vol',
#  851: '▁0000–0000',
#  852: 'zial',
#  853: 'entlich',
#  854: '▁min',
#  855: '▁deutschland',
#  856: 'mar',
#  857: '▁grün',
#  858: 'gend',
#  859: '▁bereits',
#  860: '▁stud',
#  861: 'gar',
#  862: '▁lu',
#  863: 'geboren',
#  864: '-00000',
#  865: '▁soll',
#  866: 'orn',
#  867: 'bru',
#  868: 'wir',
#  869: '▁sei',
#  870: '▁seinem',
#  871: '▁hoch',
#  872: 'spieler',
#  873: '▁:',
#  874: '▁em',
#  875: '▁jul',
#  876: 'bt',
#  877: '▁frü',
#  878: 'for',
#  879: 'geben',
#  880: '▁neben',
#  881: '▁0000/',
#  882: 'ert',
#  883: 'halb',
#  884: '▁west',
#  885: '▁mittel',
#  886: '▁aut',
#  887: 'yste',
#  888: '▁national',
#  889: 'ou',
#  890: 'ens',
#  891: 'hin',
#  892: 'uni',
#  893: '▁ind',
#  894: 'inz',
#  895: 'ings',
#  896: '▁entwick',
#  897: '▁august',
#  898: 'gew',
#  899: '▁ihn',
#  900: '▁bez',
#  901: 'ierten',
#  902: 'so',
#  903: '▁klein',
#  904: 'bach',
#  905: '▁nah',
#  906: 'gestel',
#  907: '▁selbst',
#  908: 'licher',
#  909: 'ina',
#  910: '▁bezeich',
#  911: 'ister',
#  912: 'nehmen',
#  913: 'unst',
#  914: '▁ii',
#  915: 'dent',
#  916: 'bo',
#  917: '▁beste',
#  918: 'ys',
#  919: 'istor',
#  920: 'unk',
#  921: 'ärz',
#  922: 'itt',
#  923: 'kreis',
#  924: 'atei',
#  925: '▁pf',
#  926: 'amerikan',
#  927: '▁hal',
#  928: 'olf',
#  929: '▁mon',
#  930: 'ubl',
#  931: 'hä',
#  932: 'satz',
#  933: 'üs',
#  934: 'itel',
#  935: 'abe',
#  936: '▁di',
#  937: '▁gef',
#  938: 'hann',
#  939: '▁recht',
#  940: '▁ersch',
#  941: '▁dann',
#  942: '▁rei',
#  943: 'iter',
#  944: '▁band',
#  945: 'änger',
#  946: 'hne',
#  947: 'off',
#  948: '▁lin',
#  949: '-00',
#  950: 'wohn',
#  951: 'ame',
#  952: '▁haben',
#  953: 'schieden',
#  954: 'bild',
#  955: 'ost',
#  956: 'ibt',
#  957: 'kon',
#  958: 'ußball',
#  959: 'cher',
#  960: '▁intern',
#  961: '▁datei',
#  962: 'uar',
#  963: 'ott',
#  964: '▁juni',
#  965: '▁verf',
#  966: '▁mal',
#  967: '▁nov',
#  968: '-0.',
#  969: '▁ihm',
#  970: 'kir',
#  971: '▁liegt',
#  972: 'dete',
#  973: 'ogra',
#  974: 'hand',
#  975: '▁mai',
#  976: '▁können',
#  977: 'äm',
#  978: '▁fried',
#  979: 'recht',
#  980: '▁namen',
#  981: '▁österreich',
#  982: '▁(0000–0000)',
#  983: '▁konnte',
#  984: '▁sa',
#  985: '▁famil',
#  986: '▁alle',
#  987: '▁wel',
#  988: 'dorf',
#  989: 'ionen',
#  990: 'reg',
#  991: '▁anderen',
#  992: 'prä',
#  993: 'öglich',
#  994: 'ürger',
#  995: 'asse',
#  996: 'setz',
#  997: '▁okt',
#  998: '▁juli',
#  999: 'ultur',
#  ...}

# %%
# itos[0] = 'xxunk'

# %%
# itos[1] = 'xxpad'

# %%
# voc = Vocab(itos)

# %%
data = TextLMDataBunch.from_ids(path='/mnt/data/group07/johannes/germanlm/exp_10', vocab=voc, train_ids=train_ids, valid_ids=val_ids)

# %%
data
# Out:
# TextLMDataBunch;
#
# Train: LabelList
# y: LMLabel (2978665 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: /mnt/data/group07/johannes/germanlm/exp_10
# x: LMTextList (2978665 items)
# [Text <s> ▁james ▁andrew ▁be all ▁james ▁andrew ▁be all ▁(* ▁00. ▁oktober ▁0000 ▁bei ▁mid l oth ian , ▁texas ; ▁+ ▁00. ▁februar ▁0000 ▁in ▁dallas , ▁texas ) ▁war ▁ein ▁us - amerikanischer ▁politiker . ▁zwischen ▁0000 ▁und ▁0000 ▁vertrat ▁er ▁den ▁bundesstaat ▁texas ▁im ▁us - repräsentanten haus . ▁werde gang . ▁james ▁be all ▁besuchte ▁die ▁öffentlichen ▁schulen ▁seiner ▁heimat . ▁in ▁den ▁jahren ▁0000 ▁und ▁0000 ▁unterrichtete ▁er ▁selbst ▁als ▁lehrer . ▁nach ▁einem ▁anschließenden ▁jur ast udium ▁an ▁der ▁university ▁of ▁texas ▁in ▁austin ▁und ▁seiner ▁0000 ▁erfolgten ▁zulassung ▁als ▁rechtsanwalt ▁begann ▁er ▁im ▁ell is ▁county ▁in ▁diesem ▁beruf ▁zu ▁arbeiten . ▁gleichzeitig ▁schlug ▁er ▁als ▁mitglied ▁der ▁demokratischen ▁partei ▁eine ▁politische ▁laufbahn ▁ein . ▁von ▁0000 ▁bis ▁0000 ▁war ▁er ▁abgeordneter ▁im ▁repräsentanten haus ▁von ▁texas ; ▁zwischen ▁0000 ▁und ▁0000 ▁gehörte ▁er ▁dem ▁staats senat ▁an . ▁bei ▁den ▁kongress wahlen ▁des ▁jahres ▁0000 ▁wurde ▁be all ▁im ▁fünften ▁wahl bezirk ▁von ▁texas ▁in ▁das ▁us - repräsentanten haus ▁in ▁washington , ▁d . c . ▁gewählt , ▁wo ▁er ▁am ▁0. ▁märz ▁0000 ▁die ▁nachfolge ▁von ▁cho ice ▁b . ▁rand ell ▁antrat . ▁nach ▁fünf ▁wieder wahlen ▁konnte ▁er ▁bis ▁zum ▁0. ▁märz ▁0000 ▁sechs ▁legislatur per ioden ▁im ▁kongress ▁absolvieren . ▁im ▁jahr ▁0000 ▁wurden ▁der ▁00. ▁und ▁der ▁00. ▁verfassungs zusatz ▁rat ifiziert . ▁zwischen ▁0000 ▁und ▁0000 ▁war ▁be all ▁vorsitzender ▁des ▁ausschusses ▁zur ▁kontrolle ▁der ▁ausgaben ▁des ▁justiz ministeriums . ▁im ▁jahr ▁0000 ▁verzichtete ▁er ▁auf ▁eine ▁weitere ▁kandidatur . ▁nach ▁dem ▁ende ▁seiner ▁zeit ▁im ▁us - repräsentanten haus ▁prakt izierte ▁james ▁be all ▁als ▁anwalt ▁in ▁dallas . ▁außerdem ▁wurde ▁er ▁im ▁bank geschäft ▁tätig . ▁seit ▁0000 ▁war ▁er ▁präsident ▁der ▁firma ▁texas ▁electric ▁railway . ▁er ▁starb ▁am ▁00. ▁februar ▁0000 ▁in ▁dallas , ▁wo ▁er ▁auch ▁beigesetzt ▁wurde . </s>, Text <s> ▁strategische ▁planung ▁( betriebs wirtschaft ) ▁unter ▁strateg ischer ▁planung ▁versteht ▁man ▁eine ▁unternehmen splan ung , ▁welche ▁die ▁strateg ischen ▁unternehmens ziele ▁berücksichtigt . ▁gegensatz ▁ist ▁die ▁oper ative ▁planung . ▁allgemein es . ▁strategische ▁und ▁oper ative ▁planung ▁ergeben ▁zusammen ▁die ▁unternehmen splan ung . ▁sie ▁soll ▁dafür ▁sorgen , ▁dass ▁die ▁unternehmens ziele ▁( etwa ▁gewinn maxim ierung , ▁kosten deckung sprinzip ) ▁erreicht ▁werden ▁können . ▁die ▁strategische ▁planung ▁dient ▁der ▁sicherung ▁der ▁überleben s fähigkeit ▁des ▁unternehmens . ▁wichtige ▁merkmale ▁jeder ▁planung ▁sind ▁in ▁der ▁betriebs wirtschaftslehre ▁" plan ungs gegen stand ", ▁" plan ungs sub jekt ", ▁" plan ungs daten " ▁und ▁" plan ungs horiz ont ". ▁typisch ▁für ▁strategische ▁planung ▁sind ▁ihr ▁langfrist iger ▁planungs horiz ont , ▁ungew iss heit ▁der ▁planungs daten , ▁berücksicht igung ▁lediglich ▁glob aler ▁größen ▁und ▁die ▁zuständigkeit ▁der ▁unternehmens führung . ▁haupt aufgaben ▁der ▁strateg ischen ▁planung . ▁im ▁fokus ▁der ▁strateg ischen ▁planung ▁stehen ▁als ▁" plan ungs gegen stand " ▁strategische ▁geschäfts felder ▁( sg f ) ▁eines ▁unternehmens . ▁geschäfts felder ▁sind ▁beispielsweise ▁bei ▁der ▁luft hansa ▁" pass age " ▁( personen flug verkehr ), ▁" car go " ▁( fr acht flug verkehr ) ▁und ▁" technik " ▁( wart ung , ▁instand haltung ). ▁welches ▁dieser ▁geschäfts felder ▁künftig ▁auszu bauen ▁( wach stums strategie ), ▁zu ▁halten ▁(" st abil isierungs strategie ") ▁oder ▁zu ▁verlassen ▁ist ▁( sch rum pf ungs strategie , ▁des invest itionen ), ▁hat ▁die ▁unternehmens führung ▁als ▁" plan ungs sub jekt " ▁zu ▁entscheiden . ▁die ▁strategische ▁planung ▁hat ▁auch ▁die ▁frage ▁zu ▁beant worten , ▁welches ▁markt verhalten ▁ein ▁unternehmen ▁im ▁vergleich ▁zu ▁seinen ▁wettbe wer bern ▁wählen ▁soll . ▁ver hält ▁es ▁sich ▁als ▁mengen an p asser / mengen fix ierer , ▁preis fix ierer / opt ions fix ierer , ▁dann ▁entscheidet ▁es ▁sich ▁für ▁verschiedene ▁varianten ▁von ▁markt preis ▁oder ▁absatz volumen . ▁darüber ▁hinau ...
# Path: /mnt/data/group07/johannes/germanlm/exp_10;
#
# Valid: LabelList
# y: LMLabel (299992 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: /mnt/data/group07/johannes/germanlm/exp_10
# x: LMTextList (299992 items)
# [Text <s> ▁mar sh field ▁( mass achusetts ) ▁mar sh field ▁( ur sprün glich ▁" re x ham ") ▁ist ▁eine ▁nord amerikanische ▁hafen stadt ▁und ▁ein ▁tour istik ziel ▁im ▁county ▁pl ym outh ▁im ▁marsch land ▁des ▁südosten ▁vom ▁us - bundes staates ▁massachusetts . ▁die ▁einwohnerzahl ▁beträgt ▁rund ▁00 ▁000, ▁wächst ▁in ▁sommer monaten ▁auf ▁etwa ▁00 ▁000. ▁unter ▁anderem ▁wegen ▁der ▁in ▁und ▁um ▁die ▁stadt ▁vorhandenen ▁ausgedehnten ▁bad estr ände , ▁die ▁nicht ▁nur ▁zum ▁schwimmen , ▁sondern ▁auch ▁für ▁andere ▁wasser sport arten ▁vielfach ▁nutz bar ▁sind . ▁str ände . ▁die ▁länge ▁der ▁öffentlichen ▁str ände ▁in ▁mar sh field ▁beträgt ▁über ▁0 ▁km . ▁im ▁einzelnen ▁sind ▁dies ▁die ▁zu ▁br ant ▁rock / o cean ▁bl uff ▁gehörenden ▁black man " s ▁point , ▁blue f ish ▁c ove , ▁br ant ▁rock , ▁o cean ▁bl uff , ▁re bar ▁und ▁sun r ise ▁beach ▁sowie ▁die ▁in ▁anderen ▁stadtteilen ▁befindlichen ▁str ände ▁rex ham , ▁field ston , ▁bur ke " s ▁und ▁green ▁harb or ▁beach . ▁historische ▁ereignisse . ▁am ▁mar sh field ▁gegenüber liegenden ▁nord h aken ▁der ▁halbinsel ▁" kap ▁cod ", ▁die ▁die ▁kap ▁cod ▁bucht ▁vom ▁atlantik ▁trennt , ▁befand ▁sich ▁die ▁indian ers iedlung ▁me es ha wn ▁( in ▁der ▁nähe ▁der ▁heutigen ▁stadt ▁prov inc et own ). ▁dort ▁lan deten ▁am ▁britische ▁radik ale ▁pur it aner ▁mit ▁ihrem ▁segel schiff ▁" " may fl ower " " ▁an . ▁sie ▁gründeten ▁land ein wärts ▁die ▁kolonie ▁pl ym outh . ▁im ▁dezember ▁0000 ▁fand ▁aus ▁solid arität ▁zu ▁den ▁boston er ▁prote sten ▁die ▁" mar sh field ▁te a ▁party " ▁statt . ▁von ▁einer ▁station ▁im ▁stadtteil ▁" br ant ▁rock " ▁strahl te ▁das ▁team ▁um ▁reg in ald ▁f essen den ▁und ▁ernst ▁fre dr ik ▁werner ▁alexander son ▁an ▁weihnachten ▁des ▁jahres ▁0000 ▁die ▁erste ▁hörfunk sendung ▁der ▁welt ▁mittels ▁eines ▁alexander son - altern ator ▁aus . ▁( | ▁siehe ▁auch ▁draht lose ▁aus strahl ungen ▁und ▁geschichte ▁des ▁hör funks ) </s>, Text <s> ▁ste ph ans stift ▁das ▁ste ph ans stift ▁ist ▁eine ▁0000 ▁gegründete ▁stiftung ▁des ▁bürgerlichen ▁rechts ▁und ▁eine ▁kirchliche ▁stiftung ▁mit ▁sitz ▁in ▁hannover - klee feld . ▁es ▁ist ▁mitglied ▁des ▁diakon ischen ▁werkes ▁in ▁niedersachsen ▁und ▁ist ▁in ▁unterschied lichen ▁sozialen ▁bereichen , ▁insbesondere ▁in ▁der ▁jugend - ▁und ▁alten hilfe ▁sowie ▁der ▁beruflichen ▁ausbildung , ▁der ▁fort - ▁und ▁weiterbildung ▁tätig . ▁zum ▁0. ▁januar ▁0000 ▁wurde ▁das ▁ste ph ans stift ▁mit ▁den ▁diakon ischen ▁hei men ▁k äst orf ▁in ▁der ▁dach stiftung ▁diakon ie ▁zusammen geführt . ▁geschichte . ▁gründung . ▁das ▁ste ph ans stift ▁ging ▁aus ▁dem ▁" evangel ischen ▁verein ▁zu ▁hannover " ▁hervor , ▁der ▁im ▁jahr ▁0000 ▁unter ▁anderem ▁von ▁gerhard ▁u hl horn , ▁theodor ▁lo hmann , ▁julius ▁frey tag ▁und ▁karl ▁august ▁grote ▁gegründet ▁worden ▁war . ▁der ▁verein ▁veranstaltete ▁vortrag s reihen , ▁um ▁finanz mittel ▁für ▁die ▁diakon ische ▁arbeit ▁zu ▁sammeln . ▁0000 ▁gründete ▁der ▁verein sg eist liche ▁frey tag ▁(0000-0000) ▁das ▁" hannover sche ▁sonntags blatt ", ▁durch ▁dessen ▁einnahmen , ▁die ▁der ▁verein sk asse ▁zu flossen , ▁ihm ▁ein ▁festes ▁gehalt ▁gez ahlt ▁werden ▁konnte . ▁das ▁sonntags blatt ▁informiert ▁über ▁die ▁tätigkeiten ▁des ▁verein es ▁sowie ▁der ▁diakon ischen ▁einrichtungen ▁in ▁der ▁stadt ▁hannover . ▁bei ▁der ▁mitglieder versammlung ▁des ▁evangelischen ▁vereins ▁am ▁0. ▁november ▁0000 ▁wurde ▁die ▁gründung ▁eines ▁brüder hauses ▁geplant . ▁die ▁hannover schen ▁diakon e ▁wurden ▁bis ▁dato ▁von ▁anderen , ▁un ierten ▁landes kirchen ▁ausgebildet ▁und ▁es ▁war ▁nun ▁der ▁bedarf ▁vorhanden , ▁eigene ▁diakon e ▁nach ▁dem ▁lutherischen ▁bekenntnis ▁auszu bilden . ▁der ▁theologe ▁helmut ▁gr ütter ▁beschreibt ▁dieses ▁bedürf nis ▁wenige ▁wochen ▁nach ▁der ▁mitglieder versammlung ▁in ▁seinem ▁aufsatz ▁" wir ▁müssen ▁brüder ▁haben " ▁wie ▁folgt : ▁" ro hm aterial ▁aus zuführen ▁und ▁als ▁fabrik at ▁von ▁einem ▁nachbar volk ▁the uer ▁kaufen , ▁ist ▁eine ▁schlechte ▁volkswirtschaft . ▁wir ▁müssen ▁brüder ▁haben , ▁die ▁aus ▁unser em ▁vo ...
# Path: /mnt/data/group07/johannes/germanlm/exp_10;
#
# Test: None

# %%
data.save()
