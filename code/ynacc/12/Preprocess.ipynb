# %% [markdown]
# # Preprocessing
# Bring structure to comments

# %%
from multiprocessing import cpu_count
from pathlib import Path

import dask.dataframe as ddf
import numpy as np
import pandas as pd
import spacy
import swifter
from cleantext import clean
from fastai.text import *

pd.options.display.max_colwidth = 1000

import dask

from dask.diagnostics import ProgressBar

n_cores = cpu_count()

# %% [markdown]
# ## Parameters

# %%
dask.__version__
# Out:
# '1.1.0'

# %%
# parameters in Model
max_sequence_length = 2000 # just to make to sure to have some kind of upper band
max_tokens_per_comment = 200 # truncate after

kind = 'threads_root_headline'
# kind = 'only_threads'

# kind = 'threads_headline'
max_previous = None
max_vocab = 30000
cut = 1398

base = Path('/mnt/data/group07/johannes/ynacc_proc/proper_threads')

ds_name = '_'.join([kind, 'unlimited' if max_previous is None else str(max_previous), str(max_vocab)])

if cut is not None:
    ds_name += '_cut'

ds_name
# Out:
# 'threads_root_headline_unlimited_30000_cut'

# %%
# is a problem with multiprocessing
tok = spacy.blank('en')

# truncate individual comments
def truncate(text, max_tokens_per_comment=max_tokens_per_comment):
    return str(tok.tokenizer(text)[:max_tokens_per_comment].merge())


def calc_num_tokens(text):
    return len(tok.tokenizer(text))

# def truncate_num_tokens(text):
#     tokens = tok.tokenizer(text)
#     return str(tokens[:max_tokens_per_comment].merge()), len(tokens)


def only_threads_process_text(row, n_cores=n_cores):
    the_index = row['commentindex'] + 1
    comments_before = list(row['text_proc_threads'])[
        :the_index]  # for this comment

    if not max_previous is None:
        comments_before = comments_before[-max_previous:]

    # start with this and prepend comments
    res = ' xx_thread_end'
    token_count = 1

    for i, com in enumerate(reversed(comments_before)):
        com = ' xx_comment_start ' + com + ' xx_comment_end '
        if i == len(comments_before) - 1:
            com = 'xx_thread_start ' + com

        num_tokens = calc_num_tokens(com)
        if token_count + num_tokens < max_sequence_length:
            res = com + res
            token_count += num_tokens
        else:
            break

    res = clean(res, lower=False)  # clean up too many spaces

    # simple asserts
#     print(row.name == 1)
    if row['text_proc_threads'] != 'foo':
        if not res.endswith(row['text_proc'] + ' xx_comment_end xx_thread_end'):
            print(res, row['text_proc'])
#         assert res.endswith(row['text_proc'] + ' xx_comment_end xx_thread_end')
        assert res.count(' ') < max_sequence_length

    return res


def clean_and_truncate(text, linebreaks_token=False):
    if pd.isna(text):
        return ''
    text = clean(text, lower=False, no_urls=True,
                 no_emails=True, zero_digits=True)
    if linebreaks_token:
        tl = len(text)
        text = text.replace('\n', ' xx_linebreak ')
        assert tl == len(text) or 'xx_linebreak' in text
        assert not '\n' in text
        
    text = truncate(text)
    return text


def keep_longest(rows):
    if len(rows) == 1:
        return rows.iloc[0]
    max_len = -1
    res = None
    for i in range(len(rows)):
        r = rows.iloc[i]
        if not type(r) is str and len(r['text_proc']) > max_len:
            max_len = len(r['text_proc'])
            res = r
    return res


def only_threads_process_df(df, n_cores=n_cores):
    with ProgressBar():
        df['text_proc'] = ddf.from_pandas(df, npartitions=n_cores).map_partitions(
            lambda dfx: dfx['text'].apply(lambda x: clean_and_truncate(x))).compute(scheduler="processes")

    # only drop after the cleaning
    df = df.drop_duplicates(subset=['text_proc', 'sdid', 'commentindex'])

#     keep only logest comment if there more thant two. this is important because in some comments the quotations marks are removed
    df = df.groupby(['commentindex', 'sdid'], as_index=False).apply(
        keep_longest).reset_index(drop=True)

# for smaller data this is fine
#     df['text_proc'] = df['text'].swifter.apply(lambda x: clean(x, lower=False, no_urls=True, no_emails=True, zero_digits=True))
#     df['text_proc'] = df['text_proc'].swifter.apply(truncate)

    threads = df.sort_values(by=['commentindex']).groupby(
        'sdid', as_index=False).agg({'text_proc': lambda x: list(x)})
    df_res = df.merge(threads, on='sdid', suffixes=['', '_threads'])

#     df_res['text_proc'] = df_res.swifter.apply(only_threads_process_text, axis=1)

    with ProgressBar():
        df_res['text_proc'] = ddf.from_pandas(df_res, npartitions=n_cores).map_partitions(
            lambda dfx: dfx.apply(only_threads_process_text, axis=1)).compute(scheduler="processes")

    return df_res

# %%
def threads_article_headline(df, n_cores=n_cores):
    with ProgressBar():
        df['text_proc'] = ddf.from_pandas(df, npartitions=n_cores).map_partitions(
            lambda dfx: dfx['text'].apply(lambda x: clean_and_truncate(x, linebreaks_token=True))).compute(scheduler="processes")

    # only drop after the cleaning
    df = df.drop_duplicates(subset=['text_proc', 'sdid', 'commentindex'])

#     keep only logest comment if there more thant two. this is important because in some comments the quotations marks are removed
    df = df.groupby(['commentindex', 'sdid'], as_index=False).apply(
        keep_longest).reset_index(drop=True)

    threads = df.sort_values(by=['commentindex']).groupby(
        'sdid', as_index=False).agg({'text_proc': lambda x: list(x)})
    
    df_res = df.merge(threads, on='sdid', suffixes=['', '_threads'])

    with ProgressBar():
        df_res['text_proc'] = ddf.from_pandas(df_res, npartitions=n_cores).map_partitions(
            lambda dfx: dfx.apply(only_threads_process_text, axis=1)).compute(scheduler="processes")
    
    df_res['text_proc'] = df_res.swifter.apply(lambda x: 'xx_headline_start ' + clean_and_truncate(x['headline'], linebreaks_token=True) + ' xx_headline_end ' + x['text_proc'], axis=1)
    return df_res

# %%
def threads_article_headline_article(df, n_cores=n_cores):
    with ProgressBar():
        df['text_proc'] = ddf.from_pandas(df, npartitions=n_cores).map_partitions(
            lambda dfx: dfx['text'].apply(lambda x: clean_and_truncate(x, linebreaks_token=True))).compute(scheduler="processes")

    # only drop after the cleaning
    df = df.drop_duplicates(subset=['text_proc', 'sdid', 'commentindex'])

#     keep only logest comment if there more thant two. this is important because in some comments the quotations marks are removed
    df = df.groupby(['commentindex', 'sdid'], as_index=False).apply(
        keep_longest).reset_index(drop=True)

    threads = df.sort_values(by=['commentindex']).groupby(
        'sdid', as_index=False).agg({'text_proc': lambda x: list(x)})
    
    df_res = df.merge(threads, on='sdid', suffixes=['', '_threads'])

    with ProgressBar():
        df_res['text_proc'] = ddf.from_pandas(df_res, npartitions=n_cores).map_partitions(
            lambda dfx: dfx.apply(only_threads_process_text, axis=1)).compute(scheduler="processes")
    
    df_res['text_proc'] = df_res.swifter.apply(lambda x: 'xx_headline_start ' + clean_and_truncate(x['headline'], linebreaks_token=True) + ' xx_sep ' + clean_and_truncate(x['article_text'], linebreaks_token=True) +  ' xx_headline_end ' + x['text_proc'], axis=1)
    return df_res

# %%
def process_threads_root_headline(df, n_cores=n_cores):
    with ProgressBar():
        df['text_proc'] = ddf.from_pandas(df, npartitions=n_cores).map_partitions(
            lambda dfx: dfx['text'].apply(lambda x: clean_and_truncate(x, linebreaks_token=True))).compute(scheduler="processes")

    # only drop after the cleaning
    df = df.drop_duplicates(subset=['text_proc', 'sdid', 'commentindex'])

#     keep only logest comment if there more thant two. this is important because in some comments the quotations marks are removed
    df = df.groupby(['commentindex', 'sdid'], as_index=False).apply(
        keep_longest).reset_index(drop=True)

    threads = df.sort_values(by=['commentindex']).groupby(
        'sdid', as_index=False).agg({'text_proc': lambda x: list(x)})
    
    df_res = df.merge(threads, on='sdid', suffixes=['', '_threads'])

    with ProgressBar():
        df_res['text_proc'] = ddf.from_pandas(df_res, npartitions=n_cores).map_partitions(
            lambda dfx: dfx.apply(only_threads_process_text, axis=1)).compute(scheduler="processes")
        
#     only manipulate 
    df_res['text_proc'] = df_res.swifter.apply(lambda x: 'xx_headline_start ' + clean_and_truncate(x['headline'], linebreaks_token=True) + ' xx_headline_end ' + x['text_proc'] if x['commentindex'] == 0 else x['text_proc'], axis=1)
    return df_res

# %%
process_df = None
if kind == 'only_threads':
    process_df = only_threads_process_df
    
if kind == 'threads_headline':
    process_df = threads_article_headline

if kind == 'threads_headline_article':
    process_df = threads_article_headline_article
    
if kind == 'threads_root_headline':
    process_df = process_threads_root_headline

# %% [markdown]
# # Classification Data

# %%
for f in ['train.csv', 'val.csv', 'test.csv']:
    df = pd.read_csv('~/data/ynacc_proc/replicate/split/' + f)
    df_out = process_df(df, n_cores=4)
    out_f = base/'data'/'cls'/ds_name
    ! mkdir -p {out_f}
    df_out.to_csv(out_f/f, index=False)
    del df
    del df_out
# Out:
# [########################################] | 100% Completed | 11.9s
# [########################################] | 100% Completed | 18.2s
# Pandas Apply: 100%|██████████| 7910/7910 [00:01<00:00, 5197.80it/s]
# [########################################] | 100% Completed |  7.6s
# [########################################] | 100% Completed |  8.2s
# Pandas Apply: 100%|██████████| 583/583 [00:00<00:00, 5294.76it/s]
# [########################################] | 100% Completed |  7.6s
# [########################################] | 100% Completed |  8.1s
# Pandas Apply: 100%|██████████| 553/553 [00:00<00:00, 4850.74it/s]

# %%
df_check = pd.read_csv('/mnt/data/group07/johannes/ynacc_proc/proper_threads/data/cls/threads_root_headline_unlimited_30000_cut/train.csv')

# %%
df_check.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'url', 'article_text', 'title',
#        'publish_date', 'commentid', 'clcontroversial', 'clmean',
#        'clinformative', 'cldisagreement', 'clagreement', 'clsentiment',
#        'clpersuasive', 'claudience', 'index', 'sdid', 'commentindex',
#        'headline', 'guid', 'timestamp', 'thumbs-up', 'thumbs-down', 'text',
#        'parentid', 'constructiveclass', 'sd_agreement', 'sd_type', 'sentiment',
#        'tone', 'commentagreement', 'topic', 'intendedaudience',
#        'persuasiveness', 'text_proc', 'cltopic', 'text_proc_threads'],
#       dtype='object')

# %%
df_check['text_proc']
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   xx_headline_start Math Teacher Marries 00-Year-Old Former Student, Allegedly To Avoid Her Testifying in Sex Case Against Him xx_headline_end xx_thread_start xx_comment_start She was 00, not 00. And these prosecuting lawyers act like they have never done anything wrong or questionable in their life. If they look happy, and say they are happy, just leave them alone. Why ruin someone else's life, when there really isn't any good reason to do so? xx_comment_end xx_thread_end
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       xx_thread_start xx_comment_start She was 00, not 00. And these prosecuting lawyers act like they have never done anything wrong or questionable in their life. If they look happy, and say they are happy, just leave them alone. Why ruin someone else's life, when there really isn't any good reason to do so? xx_comment_end xx_comment_start Yea, that totally makes it alright for a teacher to bang one of his students. Herp derp. xx_comment_end xx_thread_end
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                   xx_thread_start xx_comment_start She was 00, not 00. And these prosecuting lawyers act like they have never done anything wrong or questionable in their life. If they look happy, and say they are happy, just leave them alone. Why ruin someone else's life, when there really isn't any good reason to do so? xx_comment_end xx_comment_start Yea, that totally makes it alright for a teacher to bang one of his students. Herp derp. xx_comment_end xx_comment_start Yeah, because #$%$ feelings and human nature, that is all deranged. xx_comment_end xx_thread_end
# 3                                                                                                                                                                                                                                                                                                              xx_thread_start xx_comment_start She was 00, not 00. And these prosecuting lawyers act like they have never done anything wrong or questionable in their life. If they look happy, and say they are happy, just leave them alone. Why ruin someone else's life, when there really isn't any good reason to do so? xx_comment_end xx_comment_start Yea, that totally makes it alright for a teacher to bang one of his students. Herp derp. xx_comment_end xx_comment_start Yeah, because #$%$ feelings and human nature, that is all deranged. xx_comment_end xx_comment_start are you serious no its not ok to bang a student if shes in highschool and your her teacher no matter what her age is xx_comment_end xx_thread_end
# 4       xx_thread_start xx_comment_start She was 00, not 00. And these prosecuting lawyers act like they have never done anything wrong or questionable in their life. If they look happy, and say they are happy, just leave them alone. Why ruin someone else's life, when there really isn't any good reason to do so? xx_comment_end xx_comment_start Yea, that totally makes it alright for a teacher to bang one of his students. Herp derp. xx_comment_end xx_comment_start Yeah, because #$%$ feelings and human nature, that is all deranged. xx_comment_end xx_comment_start are you serious no its not ok to bang a student if shes in highschool and your her teacher no matter what her age is xx_comment_end xx_comment_start Oblivion, you are not the brightest bulb in the room. A) The incident occurred in 0000 which would make the student 00 or 00 at the time of the incident not 00 and the teacher 00 or 00. B) It is and should be against the law for high school teachers to sleep with their students. And C) A...
# 5       xx_thread_start xx_comment_start She was 00, not 00. And these prosecuting lawyers act like they have never done anything wrong or questionable in their life. If they look happy, and say they are happy, just leave them alone. Why ruin someone else's life, when there really isn't any good reason to do so? xx_comment_end xx_comment_start Yea, that totally makes it alright for a teacher to bang one of his students. Herp derp. xx_comment_end xx_comment_start Yeah, because #$%$ feelings and human nature, that is all deranged. xx_comment_end xx_comment_start are you serious no its not ok to bang a student if shes in highschool and your her teacher no matter what her age is xx_comment_end xx_comment_start Oblivion, you are not the brightest bulb in the room. A) The incident occurred in 0000 which would make the student 00 or 00 at the time of the incident not 00 and the teacher 00 or 00. B) It is and should be against the law for high school teachers to sleep with their students. And C) A...
# 6       xx_thread_start xx_comment_start She was 00, not 00. And these prosecuting lawyers act like they have never done anything wrong or questionable in their life. If they look happy, and say they are happy, just leave them alone. Why ruin someone else's life, when there really isn't any good reason to do so? xx_comment_end xx_comment_start Yea, that totally makes it alright for a teacher to bang one of his students. Herp derp. xx_comment_end xx_comment_start Yeah, because #$%$ feelings and human nature, that is all deranged. xx_comment_end xx_comment_start are you serious no its not ok to bang a student if shes in highschool and your her teacher no matter what her age is xx_comment_end xx_comment_start Oblivion, you are not the brightest bulb in the room. A) The incident occurred in 0000 which would make the student 00 or 00 at the time of the incident not 00 and the teacher 00 or 00. B) It is and should be against the law for high school teachers to sleep with their students. And C) A...
# 7                                                                                                             xx_headline_start Math Teacher Marries 00-Year-Old Former Student, Allegedly To Avoid Her Testifying in Sex Case Against Him xx_headline_end xx_thread_start xx_comment_start There is no problem with an older man marrying an adult woman no matter how wide apart they are in years. Think about that same distance in age when the girl is just 00 and the man is 00. Seems like he is a cradle robber but not really. My wife before she was had known each other almost our entire lives as children before eventually marrying in 0000 when she was 00 and I was 00. We wanted to just live together and forget marriage but her family insisted on this big elaborate wedding we both hated. We are 0 years and 0 months apart in age with me being the oldest. We were together so long everyone considered us married already. Now just passing 00 years married it was the perfect match. xx_comment_end xx_thread_end
# 8                                                                                           xx_thread_start xx_comment_start There is no problem with an older man marrying an adult woman no matter how wide apart they are in years. Think about that same distance in age when the girl is just 00 and the man is 00. Seems like he is a cradle robber but not really. My wife before she was had known each other almost our entire lives as children before eventually marrying in 0000 when she was 00 and I was 00. We wanted to just live together and forget marriage but her family insisted on this big elaborate wedding we both hated. We are 0 years and 0 months apart in age with me being the oldest. We were together so long everyone considered us married already. Now just passing 00 years married it was the perfect match. xx_comment_end xx_comment_start Women tend to live 0 to 00 years longer than men. Therefore men should usually marry women that are that much older than them. xx_comment_end xx_thread_end
# 9       xx_thread_start xx_comment_start There is no problem with an older man marrying an adult woman no matter how wide apart they are in years. Think about that same distance in age when the girl is just 00 and the man is 00. Seems like he is a cradle robber but not really. My wife before she was had known each other almost our entire lives as children before eventually marrying in 0000 when she was 00 and I was 00. We wanted to just live together and forget marriage but her family insisted on this big elaborate wedding we both hated. We are 0 years and 0 months apart in age with me being the oldest. We were together so long everyone considered us married already. Now just passing 00 years married it was the perfect match. xx_comment_end xx_comment_start Women tend to live 0 to 00 years longer than men. Therefore men should usually marry women that are that much older than them. xx_comment_end xx_comment_start Big difference. Your case the age difference is less than 0 yrs and I assume ...
# 10      xx_thread_start xx_comment_start There is no problem with an older man marrying an adult woman no matter how wide apart they are in years. Think about that same distance in age when the girl is just 00 and the man is 00. Seems like he is a cradle robber but not really. My wife before she was had known each other almost our entire lives as children before eventually marrying in 0000 when she was 00 and I was 00. We wanted to just live together and forget marriage but her family insisted on this big elaborate wedding we both hated. We are 0 years and 0 months apart in age with me being the oldest. We were together so long everyone considered us married already. Now just passing 00 years married it was the perfect match. xx_comment_end xx_comment_start Women tend to live 0 to 00 years longer than men. Therefore men should usually marry women that are that much older than them. xx_comment_end xx_comment_start Big difference. Your case the age difference is less than 0 yrs and I assume ...
# 11      xx_thread_start xx_comment_start There is no problem with an older man marrying an adult woman no matter how wide apart they are in years. Think about that same distance in age when the girl is just 00 and the man is 00. Seems like he is a cradle robber but not really. My wife before she was had known each other almost our entire lives as children before eventually marrying in 0000 when she was 00 and I was 00. We wanted to just live together and forget marriage but her family insisted on this big elaborate wedding we both hated. We are 0 years and 0 months apart in age with me being the oldest. We were together so long everyone considered us married already. Now just passing 00 years married it was the perfect match. xx_comment_end xx_comment_start Women tend to live 0 to 00 years longer than men. Therefore men should usually marry women that are that much older than them. xx_comment_end xx_comment_start Big difference. Your case the age difference is less than 0 yrs and I assume ...
# 12      xx_thread_start xx_comment_start There is no problem with an older man marrying an adult woman no matter how wide apart they are in years. Think about that same distance in age when the girl is just 00 and the man is 00. Seems like he is a cradle robber but not really. My wife before she was had known each other almost our entire lives as children before eventually marrying in 0000 when she was 00 and I was 00. We wanted to just live together and forget marriage but her family insisted on this big elaborate wedding we both hated. We are 0 years and 0 months apart in age with me being the oldest. We were together so long everyone considered us married already. Now just passing 00 years married it was the perfect match. xx_comment_end xx_comment_start Women tend to live 0 to 00 years longer than men. Therefore men should usually marry women that are that much older than them. xx_comment_end xx_comment_start Big difference. Your case the age difference is less than 0 yrs and I assume ...
# 13      xx_thread_start xx_comment_start There is no problem with an older man marrying an adult woman no matter how wide apart they are in years. Think about that same distance in age when the girl is just 00 and the man is 00. Seems like he is a cradle robber but not really. My wife before she was had known each other almost our entire lives as children before eventually marrying in 0000 when she was 00 and I was 00. We wanted to just live together and forget marriage but her family insisted on this big elaborate wedding we both hated. We are 0 years and 0 months apart in age with me being the oldest. We were together so long everyone considered us married already. Now just passing 00 years married it was the perfect match. xx_comment_end xx_comment_start Women tend to live 0 to 00 years longer than men. Therefore men should usually marry women that are that much older than them. xx_comment_end xx_comment_start Big difference. Your case the age difference is less than 0 yrs and I assume ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        xx_headline_start Math Teacher Marries 00-Year-Old Former Student, Allegedly To Avoid Her Testifying in Sex Case Against Him xx_headline_end xx_thread_start xx_comment_start I guess the law considers their case as being Cox blocked. xx_comment_end xx_thread_end
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     xx_thread_start xx_comment_start I guess the law considers their case as being Cox blocked. xx_comment_end xx_comment_start I see what you did there. Nice. xx_comment_end xx_thread_end
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        xx_thread_start xx_comment_start I guess the law considers their case as being Cox blocked. xx_comment_end xx_comment_start I see what you did there. Nice. xx_comment_end xx_comment_start VERY clever! xx_comment_end xx_thread_end
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          xx_thread_start xx_comment_start I guess the law considers their case as being Cox blocked. xx_comment_end xx_comment_start I see what you did there. Nice. xx_comment_end xx_comment_start VERY clever! xx_comment_end xx_comment_start :) Funny pun! xx_comment_end xx_thread_end
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       xx_headline_start Math Teacher Marries 00-Year-Old Former Student, Allegedly To Avoid Her Testifying in Sex Case Against Him xx_headline_end xx_thread_start xx_comment_start You could argue the case that at the time she was a minor and in school, and require her testimony on those grounds. Plus, if there are pictures of them during the time indicated, her testimony may not be needed, as those pics and texts are dated and should be enough to convict him. xx_comment_end xx_thread_end
# 19                                                                                                                                                                                                                                                                                                                                                                          xx_thread_start xx_comment_start You could argue the case that at the time she was a minor and in school, and require her testimony on those grounds. Plus, if there are pictures of them during the time indicated, her testimony may not be needed, as those pics and texts are dated and should be enough to convict him. xx_comment_end xx_comment_start She could just refuse to say anything. They can't force her to talk. What are they going to do, jail her, the victim? These two seem happy, can't the prosecutors go find some real crime to solve? Maybe it's time to slash law enforcement budget and cut my taxes too. xx_comment_end xx_thread_end
# 20                                                                                                                                                                                                                                                                             xx_thread_start xx_comment_start You could argue the case that at the time she was a minor and in school, and require her testimony on those grounds. Plus, if there are pictures of them during the time indicated, her testimony may not be needed, as those pics and texts are dated and should be enough to convict him. xx_comment_end xx_comment_start She could just refuse to say anything. They can't force her to talk. What are they going to do, jail her, the victim? These two seem happy, can't the prosecutors go find some real crime to solve? Maybe it's time to slash law enforcement budget and cut my taxes too. xx_comment_end xx_comment_start Maybe your just into humping underage kids, Michael Jackson. xx_comment_end xx_thread_end
# 21                                                                                                 xx_thread_start xx_comment_start You could argue the case that at the time she was a minor and in school, and require her testimony on those grounds. Plus, if there are pictures of them during the time indicated, her testimony may not be needed, as those pics and texts are dated and should be enough to convict him. xx_comment_end xx_comment_start She could just refuse to say anything. They can't force her to talk. What are they going to do, jail her, the victim? These two seem happy, can't the prosecutors go find some real crime to solve? Maybe it's time to slash law enforcement budget and cut my taxes too. xx_comment_end xx_comment_start Maybe your just into humping underage kids, Michael Jackson. xx_comment_end xx_comment_start @USERNAME - good call. We should do the same for all rape victims; punish them until they take the stand against the accused. [endTrolling] xx_comment_end xx_thread_end
# 22      xx_thread_start xx_comment_start You could argue the case that at the time she was a minor and in school, and require her testimony on those grounds. Plus, if there are pictures of them during the time indicated, her testimony may not be needed, as those pics and texts are dated and should be enough to convict him. xx_comment_end xx_comment_start She could just refuse to say anything. They can't force her to talk. What are they going to do, jail her, the victim? These two seem happy, can't the prosecutors go find some real crime to solve? Maybe it's time to slash law enforcement budget and cut my taxes too. xx_comment_end xx_comment_start Maybe your just into humping underage kids, Michael Jackson. xx_comment_end xx_comment_start @USERNAME - good call. We should do the same for all rape victims; punish them until they take the stand against the accused. [endTrolling] xx_comment_end xx_comment_start No, we should eleminate the stupid laws that protect predators like this. It leads t...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                 xx_headline_start Math Teacher Marries 00-Year-Old Former Student, Allegedly To Avoid Her Testifying in Sex Case Against Him xx_headline_end xx_thread_start xx_comment_start To the American mind, a child is a magical, innocent fairy creature incapable of knowing right from wrong or having any sort of physical urges common place to other human beings. They simply cannot and do not see children as simply being merely juvenile humans. -- J.R.R. Tolkien (Yes, the guy who wrote the Hobbits and Lord of the Rings - wrote some fascinating observances of this.). xx_comment_end xx_thread_end
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            xx_thread_start xx_comment_start To the American mind, a child is a magical, innocent fairy creature incapable of knowing right from wrong or having any sort of physical urges common place to other human beings. They simply cannot and do not see children as simply being merely juvenile humans. -- J.R.R. Tolkien (Yes, the guy who wrote the Hobbits and Lord of the Rings - wrote some fascinating observances of this.). xx_comment_end xx_comment_start Haven't you already posted this comment? Move on. xx_comment_end xx_thread_end
# 25                                                                                                                                                                                                                                               xx_thread_start xx_comment_start To the American mind, a child is a magical, innocent fairy creature incapable of knowing right from wrong or having any sort of physical urges common place to other human beings. They simply cannot and do not see children as simply being merely juvenile humans. -- J.R.R. Tolkien (Yes, the guy who wrote the Hobbits and Lord of the Rings - wrote some fascinating observances of this.). xx_comment_end xx_comment_start Haven't you already posted this comment? Move on. xx_comment_end xx_comment_start What the hell do Hobbits and Lord of the Rings have to do with Pedophiles? Bubba just wanted some young stuff and knew is he did't Marry her, when he went to jail, (he) would be the one getting "stuffed"! xx_comment_end xx_thread_end
# 26                                                     xx_thread_start xx_comment_start To the American mind, a child is a magical, innocent fairy creature incapable of knowing right from wrong or having any sort of physical urges common place to other human beings. They simply cannot and do not see children as simply being merely juvenile humans. -- J.R.R. Tolkien (Yes, the guy who wrote the Hobbits and Lord of the Rings - wrote some fascinating observances of this.). xx_comment_end xx_comment_start Haven't you already posted this comment? Move on. xx_comment_end xx_comment_start What the hell do Hobbits and Lord of the Rings have to do with Pedophiles? Bubba just wanted some young stuff and knew is he did't Marry her, when he went to jail, (he) would be the one getting "stuffed"! xx_comment_end xx_comment_start @USERNAME sex with a 00 year old is hardly what anyone would call pedophilia, especially when right across the state line in GA the age of consent is 00. xx_comment_end xx_thread_end
# 27      xx_thread_start xx_comment_start To the American mind, a child is a magical, innocent fairy creature incapable of knowing right from wrong or having any sort of physical urges common place to other human beings. They simply cannot and do not see children as simply being merely juvenile humans. -- J.R.R. Tolkien (Yes, the guy who wrote the Hobbits and Lord of the Rings - wrote some fascinating observances of this.). xx_comment_end xx_comment_start Haven't you already posted this comment? Move on. xx_comment_end xx_comment_start What the hell do Hobbits and Lord of the Rings have to do with Pedophiles? Bubba just wanted some young stuff and knew is he did't Marry her, when he went to jail, (he) would be the one getting "stuffed"! xx_comment_end xx_comment_start @USERNAME sex with a 00 year old is hardly what anyone would call pedophilia, especially when right across the state line in GA the age of consent is 00. xx_comment_end xx_comment_start Nate had a girlfriend once but she left ...
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                    xx_headline_start Math Teacher Marries 00-Year-Old Former Student, Allegedly To Avoid Her Testifying in Sex Case Against Him xx_headline_end xx_thread_start xx_comment_start When I was in high school, there was a girl in my class who set her sights on the boys' gym teacher. Originally I think she did it on a dare, then, as she was trying to seduce him, she fell in love with him. He ended up quitting his job, and they got married and started a family. I still remember reading their wedding announcement in the newspaper. xx_comment_end xx_thread_end
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                              xx_thread_start xx_comment_start When I was in high school, there was a girl in my class who set her sights on the boys' gym teacher. Originally I think she did it on a dare, then, as she was trying to seduce him, she fell in love with him. He ended up quitting his job, and they got married and started a family. I still remember reading their wedding announcement in the newspaper. xx_comment_end xx_comment_start Same thing happened in my highschool...but it was a math teacher. Last i heard they were still married 00 years later with 0 kids. xx_comment_end xx_thread_end
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 7880    xx_thread_start xx_comment_start The lady went overboard, esp cussing, YET, this is not just airlines. Anything big, including gvotventities are treating ones horrible in service, yet with also medical rights. The staff of bigwigs do often escalate situations vs care about the customers time, money, effort etc. I'm sure this lady has to save up for ions to take her children on this vacation, and for a year Ber kids spoke about it, as well as could not afford again. This was a broken mom, dejected, helpless... xx_comment_end xx_comment_start Younger, I always made sure customers were treated well, had a great experience and did not es a late it by being rude, lying, or shutting them down. Organizational Psychology is so needed in many bigwig areas. Its not e en safe, to be a jerk when it comes to taking up Masa hours, time, money of people. xx_comment_end xx_comment_start Yeah, but how does going off on the desk folks that can't do squat about the situation and are reporting what th...
# 7881    xx_thread_start xx_comment_start The lady went overboard, esp cussing, YET, this is not just airlines. Anything big, including gvotventities are treating ones horrible in service, yet with also medical rights. The staff of bigwigs do often escalate situations vs care about the customers time, money, effort etc. I'm sure this lady has to save up for ions to take her children on this vacation, and for a year Ber kids spoke about it, as well as could not afford again. This was a broken mom, dejected, helpless... xx_comment_end xx_comment_start Younger, I always made sure customers were treated well, had a great experience and did not es a late it by being rude, lying, or shutting them down. Organizational Psychology is so needed in many bigwig areas. Its not e en safe, to be a jerk when it comes to taking up Masa hours, time, money of people. xx_comment_end xx_comment_start Yeah, but how does going off on the desk folks that can't do squat about the situation and are reporting what th...
# 7882    xx_headline_start Bill Gates 'surprised' who's NOT in Panama Papers xx_headline_end xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly...
# 7883    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7884    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7885    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7886    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7887    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7888    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7889    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7890    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7891    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7892    xx_thread_start xx_comment_start Mr Gates, the root cause of poverty in Muslim country's is two fold. Number one, The leaders these countrys take 00% of all money given to the country for the purposes of helping to resolve the poverty problem and hide it in overseas bank accounts for themselves. Number 0, the religion, by it's design, keeps its people down. History shows this to be true. The leaders of these Muslim country's will actually tell you that the people of these country's are very happy being and living in poverty. There is a possible solution. If the USA feels it is necessary to give money to these muslim countrys it should be done through and by USA citizens. Any money, food, supplies or any other type of support needs to be directly managed by non-muslim ex patriots actually living in those countrys. Oversight for these people (those who manage the programs) needs to be done on a weekly basis to ensure the USA citizens are actually doing what it is they are supposed to...
# 7893                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             xx_headline_start Watch This Tesla's Autopilot Save a Driver's Life xx_headline_end xx_thread_start xx_comment_start The only great thing to self driving cars is that hopefully traffic congestion will not be as bad. The reason there's traffic, not accident bound, is because everyone is driving at different speeds. There's always those that are speeding and those that speed. These inconsistent speeds cause traffic. xx_comment_end xx_thread_end
# 7894                                                                                                                                                                                                                                                                                                                                                                                                                xx_thread_start xx_comment_start The only great thing to self driving cars is that hopefully traffic congestion will not be as bad. The reason there's traffic, not accident bound, is because everyone is driving at different speeds. There's always those that are speeding and those that speed. These inconsistent speeds cause traffic. xx_comment_end xx_comment_start To add to what you said, traffic is caused by the points you mentioned combined with inconsiderate or just plain stupid drivers that wants to hog the faster lanes while moving slower than the car to his right xx_comment_end xx_thread_end
# 7895                                                                                                                                                                                                                                                              xx_thread_start xx_comment_start The only great thing to self driving cars is that hopefully traffic congestion will not be as bad. The reason there's traffic, not accident bound, is because everyone is driving at different speeds. There's always those that are speeding and those that speed. These inconsistent speeds cause traffic. xx_comment_end xx_comment_start To add to what you said, traffic is caused by the points you mentioned combined with inconsiderate or just plain stupid drivers that wants to hog the faster lanes while moving slower than the car to his right xx_comment_end xx_comment_start I agree, they should make a law for Prius drivers, if you drive a Prius, stay out of the fast lane or pay a fine! xx_comment_end xx_thread_end
# 7896    xx_thread_start xx_comment_start The only great thing to self driving cars is that hopefully traffic congestion will not be as bad. The reason there's traffic, not accident bound, is because everyone is driving at different speeds. There's always those that are speeding and those that speed. These inconsistent speeds cause traffic. xx_comment_end xx_comment_start To add to what you said, traffic is caused by the points you mentioned combined with inconsiderate or just plain stupid drivers that wants to hog the faster lanes while moving slower than the car to his right xx_comment_end xx_comment_start I agree, they should make a law for Prius drivers, if you drive a Prius, stay out of the fast lane or pay a fine! xx_comment_end xx_comment_start I speed every time I touch the interstate. Normally doing about 00-00 in a 00 and honestly it's a bad habit of mine. Luckily, I only see wrecks on people who actually do the speed limit, usually due to the fact that I may be speeding, but I'm ...
# 7897    xx_thread_start xx_comment_start The only great thing to self driving cars is that hopefully traffic congestion will not be as bad. The reason there's traffic, not accident bound, is because everyone is driving at different speeds. There's always those that are speeding and those that speed. These inconsistent speeds cause traffic. xx_comment_end xx_comment_start To add to what you said, traffic is caused by the points you mentioned combined with inconsiderate or just plain stupid drivers that wants to hog the faster lanes while moving slower than the car to his right xx_comment_end xx_comment_start I agree, they should make a law for Prius drivers, if you drive a Prius, stay out of the fast lane or pay a fine! xx_comment_end xx_comment_start I speed every time I touch the interstate. Normally doing about 00-00 in a 00 and honestly it's a bad habit of mine. Luckily, I only see wrecks on people who actually do the speed limit, usually due to the fact that I may be speeding, but I'm ...
# 7898                                                                                                                                                                                                                                                                               xx_headline_start Samantha Bee slams 'bigots' who oppose Harriet Tubman's place on the new $00 bill xx_headline_end xx_thread_start xx_comment_start I don't know who this samatha bee dip stick is but I do know who Andrew Jackson was! He was an amazing man to anyone who is capable of reading history. As for this ignorant Bee chick it is NOT only "white men" who don't want this change nor is it just bigots that don't want this change. I am a woman, NOT anywhere close to being a bigot, and I certainly don't want Jackson taken off his rightful place on the $00. I won't ever use one of these new $00's!!! In fact as a relative of Andrew Jackson I am seeking an attorney to sue the gov. on this matter! xx_comment_end xx_thread_end
# 7899                                                                                                                                                                                                                                                                                                                 xx_thread_start xx_comment_start I don't know who this samatha bee dip stick is but I do know who Andrew Jackson was! He was an amazing man to anyone who is capable of reading history. As for this ignorant Bee chick it is NOT only "white men" who don't want this change nor is it just bigots that don't want this change. I am a woman, NOT anywhere close to being a bigot, and I certainly don't want Jackson taken off his rightful place on the $00. I won't ever use one of these new $00's!!! In fact as a relative of Andrew Jackson I am seeking an attorney to sue the gov. on this matter! xx_comment_end xx_comment_start Andrew Jackson was an arrogant, genocidal maniac. xx_comment_end xx_thread_end
# 7900                                                                                                                                                                                                                                                    xx_thread_start xx_comment_start I don't know who this samatha bee dip stick is but I do know who Andrew Jackson was! He was an amazing man to anyone who is capable of reading history. As for this ignorant Bee chick it is NOT only "white men" who don't want this change nor is it just bigots that don't want this change. I am a woman, NOT anywhere close to being a bigot, and I certainly don't want Jackson taken off his rightful place on the $00. I won't ever use one of these new $00's!!! In fact as a relative of Andrew Jackson I am seeking an attorney to sue the gov. on this matter! xx_comment_end xx_comment_start Andrew Jackson was an arrogant, genocidal maniac. xx_comment_end xx_comment_start Good luck with that, nutjob. xx_comment_end xx_thread_end
# 7901    xx_thread_start xx_comment_start I don't know who this samatha bee dip stick is but I do know who Andrew Jackson was! He was an amazing man to anyone who is capable of reading history. As for this ignorant Bee chick it is NOT only "white men" who don't want this change nor is it just bigots that don't want this change. I am a woman, NOT anywhere close to being a bigot, and I certainly don't want Jackson taken off his rightful place on the $00. I won't ever use one of these new $00's!!! In fact as a relative of Andrew Jackson I am seeking an attorney to sue the gov. on this matter! xx_comment_end xx_comment_start Andrew Jackson was an arrogant, genocidal maniac. xx_comment_end xx_comment_start Good luck with that, nutjob. xx_comment_end xx_comment_start @USERNAME sue the government over a slavemaster! You "white guys" are so sensitive it's easy for you to say all black people are on welfare and quickly quote black on black crime statistics , now the government want to remove a racis...
# 7902    xx_thread_start xx_comment_start I don't know who this samatha bee dip stick is but I do know who Andrew Jackson was! He was an amazing man to anyone who is capable of reading history. As for this ignorant Bee chick it is NOT only "white men" who don't want this change nor is it just bigots that don't want this change. I am a woman, NOT anywhere close to being a bigot, and I certainly don't want Jackson taken off his rightful place on the $00. I won't ever use one of these new $00's!!! In fact as a relative of Andrew Jackson I am seeking an attorney to sue the gov. on this matter! xx_comment_end xx_comment_start Andrew Jackson was an arrogant, genocidal maniac. xx_comment_end xx_comment_start Good luck with that, nutjob. xx_comment_end xx_comment_start @USERNAME sue the government over a slavemaster! You "white guys" are so sensitive it's easy for you to say all black people are on welfare and quickly quote black on black crime statistics , now the government want to remove a racis...
# 7903    xx_thread_start xx_comment_start I don't know who this samatha bee dip stick is but I do know who Andrew Jackson was! He was an amazing man to anyone who is capable of reading history. As for this ignorant Bee chick it is NOT only "white men" who don't want this change nor is it just bigots that don't want this change. I am a woman, NOT anywhere close to being a bigot, and I certainly don't want Jackson taken off his rightful place on the $00. I won't ever use one of these new $00's!!! In fact as a relative of Andrew Jackson I am seeking an attorney to sue the gov. on this matter! xx_comment_end xx_comment_start Andrew Jackson was an arrogant, genocidal maniac. xx_comment_end xx_comment_start Good luck with that, nutjob. xx_comment_end xx_comment_start @USERNAME sue the government over a slavemaster! You "white guys" are so sensitive it's easy for you to say all black people are on welfare and quickly quote black on black crime statistics , now the government want to remove a racis...
# 7904    xx_thread_start xx_comment_start I don't know who this samatha bee dip stick is but I do know who Andrew Jackson was! He was an amazing man to anyone who is capable of reading history. As for this ignorant Bee chick it is NOT only "white men" who don't want this change nor is it just bigots that don't want this change. I am a woman, NOT anywhere close to being a bigot, and I certainly don't want Jackson taken off his rightful place on the $00. I won't ever use one of these new $00's!!! In fact as a relative of Andrew Jackson I am seeking an attorney to sue the gov. on this matter! xx_comment_end xx_comment_start Andrew Jackson was an arrogant, genocidal maniac. xx_comment_end xx_comment_start Good luck with that, nutjob. xx_comment_end xx_comment_start @USERNAME sue the government over a slavemaster! You "white guys" are so sensitive it's easy for you to say all black people are on welfare and quickly quote black on black crime statistics , now the government want to remove a racis...
# 7905    xx_thread_start xx_comment_start I don't know who this samatha bee dip stick is but I do know who Andrew Jackson was! He was an amazing man to anyone who is capable of reading history. As for this ignorant Bee chick it is NOT only "white men" who don't want this change nor is it just bigots that don't want this change. I am a woman, NOT anywhere close to being a bigot, and I certainly don't want Jackson taken off his rightful place on the $00. I won't ever use one of these new $00's!!! In fact as a relative of Andrew Jackson I am seeking an attorney to sue the gov. on this matter! xx_comment_end xx_comment_start Andrew Jackson was an arrogant, genocidal maniac. xx_comment_end xx_comment_start Good luck with that, nutjob. xx_comment_end xx_comment_start @USERNAME sue the government over a slavemaster! You "white guys" are so sensitive it's easy for you to say all black people are on welfare and quickly quote black on black crime statistics , now the government want to remove a racis...
# 7906                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          xx_headline_start This Woman Has Been Allowed to Run at Least 00 Horrifying Daycares Because of a Crazy Loophole xx_headline_end xx_thread_start xx_comment_start What kind of parent sends their child to daycare in an old, dilapidated warehouse? xx_comment_end xx_thread_end
# 7907                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          xx_thread_start xx_comment_start What kind of parent sends their child to daycare in an old, dilapidated warehouse? xx_comment_end xx_comment_start Parents that are making minimum wage, because NO ONE gave them instructions on birth control, or said they should wait until they could afford them. There are a LOT of families in this country that still think a women should be married by 00 and pregnant 00 minutes later. xx_comment_end xx_thread_end
# 7908                                                                                                                                                                                                                                                                                                                                                                                                                                xx_thread_start xx_comment_start What kind of parent sends their child to daycare in an old, dilapidated warehouse? xx_comment_end xx_comment_start Parents that are making minimum wage, because NO ONE gave them instructions on birth control, or said they should wait until they could afford them. There are a LOT of families in this country that still think a women should be married by 00 and pregnant 00 minutes later. xx_comment_end xx_comment_start There are also a lot of stupid, irresponsible women that know how to use birth control and choose not to. xx_comment_end xx_thread_end
# 7909                                                                                                                                                                                                                                                                                                                                                       xx_thread_start xx_comment_start What kind of parent sends their child to daycare in an old, dilapidated warehouse? xx_comment_end xx_comment_start Parents that are making minimum wage, because NO ONE gave them instructions on birth control, or said they should wait until they could afford them. There are a LOT of families in this country that still think a women should be married by 00 and pregnant 00 minutes later. xx_comment_end xx_comment_start There are also a lot of stupid, irresponsible women that know how to use birth control and choose not to. xx_comment_end xx_comment_start takes two to make that mistake, robert.. xx_comment_end xx_thread_end
# Name: text_proc, Length: 7910, dtype: object

# %% [markdown]
# # Language Model Data

# %% [markdown]
# ## To Threads

# %%
dfs = []
for f in ['train.csv', 'val.csv']:
    df = pd.read_csv('~/data/ynacc_proc/replicate/lmdata_complete/' + f)
    dfs.append(df)
df = pd.concat(dfs, verify_integrity=True, ignore_index=True)

if kind == 'threads_headline_article':
    art = pd.read_csv('/home/group7/masters-thesis/ynacc/00 data/04 all articles/articles.csv')
    art = art[['text', 'url']]
    art = art.rename(columns={'text': 'article_text'})
    df = df.merge(art, how="left")

# %%
df_out = process_df(df, n_cores=n_cores - 1)
out_f = base/'data'/'lm'/ds_name
! mkdir -p {out_f}

df_lm_train = df_out[:190000]
df_lm_train.to_csv(out_f/'train.csv', index=False)

df_lm_val = df_out[190000:]
df_lm_val.to_csv(out_f/'val.csv', index=False)

del df
del df_out
# Out:
# [########################################] | 100% Completed |  1min 36.8s
# [                                        ] | 0% Completed | 14.0sxx_thread_start xx_comment_start How do we know that global warming is caused by humans? xx_linebreak The 'natural' warming cycles of interglacial periods here on Earth are quite well-known and documented. And yes, Co0 did not cause them, but instead were caused by a variety of cosmic and orbital effects associated with the Milankovic Cycle. And in each of these interglacial events in the past, Co0 levels increased after the temperature increased, by as much as 000 years, thus reinstating the necessary physical equilibrium between atmospheric Co0 and temperature which has been well-known and documented since the nineteenth century (Arrhenius, 0000). This sequence has been carefully and precisely documented for the past 000,000 years through the use of ice-core data from Greenland and the Antarctic as well, and all indications from the deeper past via marine sediment cores and other methods indicate the same has been the case as far back as we are able to look. NOTE; this does not mean that Co0 and Methane are not heat-trapping atmospheric greenhouse gases, and especially in association with xx_comment_end xx_thread_end How do we know that global warming is caused by humans? xx_linebreak  The 'natural' warming cycles of interglacial periods here on Earth are quite well-known and documented. And yes, Co0 did not cause them, but instead were caused by a variety of cosmic and orbital effects associated with the Milankovic Cycle. And in each of these interglacial events in the past, Co0 levels increased after the temperature increased, by as much as 000 years, thus reinstating the necessary physical equilibrium between atmospheric Co0 and temperature which has been well-known and documented since the nineteenth century (Arrhenius, 0000). This sequence has been carefully and precisely documented for the past 000,000 years through the use of ice-core data from Greenland and the Antarctic as well, and all indications from the deeper past via marine sediment cores and other methods indicate the same has been the case as far back as we are able to look. NOTE; this does not mean that Co0 and Methane are not heat-trapping atmospheric greenhouse gases, and especially in association with
# [####                                    ] | 10% Completed |  1min 53.9sxx_thread_start xx_comment_start Lol. I JUST started taking low dosage prescription sleeping pills and took tonight's dose about half an hour ago. Now, I don't know if it is due to the pills, - they sure feel like they're kicking in, but ......... these comments are just crazy! Hehheeh. Most of the men are like DAMN YEAH, SON! and I find that pretty funny. Then there are A LOT of posts saying the teacher is hot. Errrrrrrmmmmm, are we looking at different images? She looks like Santa Clause's sister who left home to take up boxing :D. Lastly, ironically, in a thread about schools, and teachers, the writing style, the punctuation used and not used, the spelling, the grammar on a lot of these posts is horrific and alarming! My jaw drops at almost every other comment because I can't believe how bad the English language has become!!! America! Grab your teacher now and doe si doe! Winter is coming and the night is long and full of terrors. xx_comment_end xx_comment_start Here's something to think about as you doze off... And it just may give you nightmares! What if this woman had gotten pregnant from the 00-year-old? If he was a virgin before having sex with her, he would have no STD's. She would probably prefer having sex with him without a condom. He wouldn't have a clue as to how to use a condom or the real need to with a woman like her. Imagine this kid at age 00 having to pay her child support... xx_comment_end xx_comment_start Ooooh. I would bet she would try to pass it off as the husbands, but oooh what if there were texts saying there was a baby, \\ MIND BLOWN///// xx_comment_end xx_thread_end Ooooh. I would bet she would try to pass it off as the husbands, but oooh what if there were texts saying there was a baby, \\\ MIND BLOWN/////
# [########################################] | 100% Completed |  3min  2.7s
# Pandas Apply: 100%|██████████| 222411/222411 [00:55<00:00, 4007.76it/s]

# %% [markdown]
# ## Prepare FastAI data

# %%
EX_PA = base/'exp'/'lm'/ds_name

data_lm = TextLMDataBunch.from_df(EX_PA, df_lm_train, df_lm_val, max_vocab=max_vocab, text_cols='text_proc')

itos_new = data_lm.train_dl.vocab.itos

# move special tokens to the beginning of the vocab we can know their ids
specials = ['xx_comment_start', 'xx_comment_end', 'xx_thread_start', 'xx_thread_end']
for s in specials:
    itos_new.remove(s)
    itos_new.insert(2, s)

itos_new
# Out:
# ['xxunk',
#  'xxpad',
#  'xx_thread_end',
#  'xx_thread_start',
#  'xx_comment_end',
#  'xx_comment_start',
#  'xxbos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  '.',
#  'the',
#  ',',
#  'to',
#  'and',
#  'a',
#  'of',
#  'you',
#  'is',
#  'that',
#  'i',
#  'it',
#  'in',
#  'are',
#  '"',
#  'for',
#  'not',
#  '?',
#  "n't",
#  'they',
#  "'s",
#  'have',
#  'do',
#  'be',
#  'with',
#  'this',
#  'was',
#  'on',
#  '!',
#  'he',
#  'as',
#  'your',
#  'but',
#  'people',
#  'if',
#  'or',
#  'what',
#  'all',
#  '-',
#  'so',
#  'just',
#  'we',
#  'their',
#  'who',
#  'like',
#  'about',
#  'no',
#  'would',
#  'she',
#  'will',
#  '0',
#  'there',
#  '...',
#  'at',
#  'can',
#  'one',
#  'my',
#  'her',
#  '00',
#  'has',
#  'from',
#  'them',
#  'by',
#  'out',
#  'an',
#  'when',
#  'get',
#  'his',
#  'up',
#  '$',
#  'how',
#  'because',
#  'did',
#  'more',
#  '4',
#  ')',
#  'know',
#  'does',
#  'were',
#  '(',
#  'why',
#  'should',
#  'me',
#  'think',
#  "'",
#  'had',
#  'then',
#  'only',
#  '%',
#  'than',
#  'been',
#  'some',
#  'time',
#  'any',
#  'other',
#  'even',
#  'want',
#  'being',
#  'right',
#  'these',
#  'go',
#  'trump',
#  'now',
#  'our',
#  'make',
#  'him',
#  'never',
#  'white',
#  'way',
#  'see',
#  'black',
#  'us',
#  'many',
#  'over',
#  "'re",
#  'could',
#  'those',
#  'years',
#  'good',
#  'say',
#  "'m",
#  'going',
#  'need',
#  'well',
#  'women',
#  'most',
#  'man',
#  'too',
#  'into',
#  'really',
#  'same',
#  'much',
#  '#',
#  'life',
#  'also',
#  ':',
#  'very',
#  'god',
#  '/',
#  'someone',
#  'where',
#  'said',
#  'which',
#  'ca',
#  'back',
#  'take',
#  'person',
#  'woman',
#  'still',
#  'am',
#  'nothing',
#  'thing',
#  'believe',
#  'country',
#  'here',
#  'own',
#  'after',
#  'world',
#  '..',
#  '@username',
#  'every',
#  'something',
#  'old',
#  'look',
#  'off',
#  'down',
#  'its',
#  'first',
#  'money',
#  'men',
#  'xx_headline_start',
#  'xx_headline_end',
#  'use',
#  'another',
#  'before',
#  'let',
#  'anything',
#  'better',
#  'anyone',
#  'things',
#  'ever',
#  'made',
#  'wrong',
#  'got',
#  'children',
#  'kids',
#  'sure',
#  'work',
#  'actually',
#  'law',
#  'year',
#  'day',
#  'while',
#  'problem',
#  'always',
#  '000',
#  'everyone',
#  'little',
#  'against',
#  'come',
#  'two',
#  'put',
#  'child',
#  'keep',
#  'america',
#  'stop',
#  'real',
#  'love',
#  'maybe',
#  'gay',
#  'point',
#  'tell',
#  'new',
#  'hillary',
#  'stupid',
#  "'ve",
#  'read',
#  'live',
#  'bad',
#  'may',
#  'such',
#  'fact',
#  'since',
#  'american',
#  'yes',
#  'around',
#  'long',
#  'racist',
#  'care',
#  'show',
#  'great',
#  'obama',
#  'again',
#  'blacks',
#  'lot',
#  'agree',
#  'doing',
#  'family',
#  '5',
#  'give',
#  'feel',
#  'vote',
#  'else',
#  'both',
#  'find',
#  'government',
#  'big',
#  ';',
#  'without',
#  'others',
#  'hate',
#  'enough',
#  'guy',
#  'away',
#  "'ll",
#  'gun',
#  'saying',
#  'understand',
#  'true',
#  'trying',
#  'pay',
#  'matter',
#  'must',
#  'try',
#  'change',
#  'done',
#  'public',
#  'business',
#  'state',
#  'article',
#  'having',
#  'probably',
#  'mean',
#  'reason',
#  'nt',
#  'last',
#  'job',
#  'story',
#  'makes',
#  'school',
#  'free',
#  'getting',
#  'yet',
#  'help',
#  'left',
#  'called',
#  'used',
#  'different',
#  'either',
#  'part',
#  'says',
#  'sex',
#  '&',
#  'lol',
#  'everything',
#  'laws',
#  'president',
#  'clinton',
#  'race',
#  'through',
#  'far',
#  'making',
#  '--',
#  'until',
#  'bible',
#  'few',
#  'media',
#  'already',
#  'parents',
#  'yourself',
#  'thought',
#  'rights',
#  'best',
#  'party',
#  'might',
#  'less',
#  'call',
#  'themselves',
#  'please',
#  'oh',
#  'guess',
#  'wo',
#  'place',
#  'liberal',
#  'americans',
#  'etc',
#  "'d",
#  'home',
#  'under',
#  'bathroom',
#  'idiot',
#  'times',
#  'today',
#  'hard',
#  'least',
#  'name',
#  'comment',
#  'end',
#  'support',
#  'death',
#  'instead',
#  'sorry',
#  'kind',
#  'high',
#  'republican',
#  'history',
#  'human',
#  'next',
#  'issue',
#  'police',
#  'states',
#  'once',
#  'needs',
#  'hope',
#  'though',
#  'told',
#  'truth',
#  'using',
#  'news',
#  'went',
#  'ago',
#  'lives',
#  'young',
#  'religion',
#  's',
#  'post',
#  'mother',
#  'wants',
#  'each',
#  'whites',
#  'talking',
#  'start',
#  'comments',
#  'exactly',
#  'bill',
#  'word',
#  'house',
#  'cruz',
#  'pretty',
#  'society',
#  'whole',
#  'age',
#  'girl',
#  'prince',
#  'case',
#  'sense',
#  'means',
#  'control',
#  'course',
#  'between',
#  'kill',
#  'able',
#  'happen',
#  'earth',
#  'male',
#  'hell',
#  'religious',
#  'leave',
#  'happened',
#  'jobs',
#  'mind',
#  'idea',
#  'poor',
#  'tax',
#  'science',
#  'ones',
#  'sad',
#  'living',
#  'ask',
#  'yeah',
#  'self',
#  'baby',
#  'run',
#  'ignorant',
#  'gets',
#  'transgender',
#  'days',
#  'rest',
#  'christians',
#  'dead',
#  'goes',
#  'looking',
#  'however',
#  'simply',
#  'seems',
#  'group',
#  'came',
#  'christian',
#  'remember',
#  'system',
#  'liberals',
#  'head',
#  'female',
#  'jesus',
#  'room',
#  'food',
#  'born',
#  'seen',
#  'power',
#  'become',
#  'car',
#  'war',
#  'face',
#  'found',
#  'facts',
#  'kid',
#  'wife',
#  'racism',
#  'based',
#  'taking',
#  'choice',
#  'sexual',
#  'illegal',
#  'ok',
#  'yahoo',
#  'working',
#  'republicans',
#  'talk',
#  'crime',
#  'daughter',
#  'took',
#  'body',
#  'water',
#  'comes',
#  'lost',
#  'thinking',
#  'issues',
#  'political',
#  'killed',
#  'question',
#  'whatever',
#  'cause',
#  'majority',
#  'deal',
#  'wanted',
#  'knows',
#  'folks',
#  'rather',
#  'looks',
#  'drugs',
#  'full',
#  'hear',
#  'opinion',
#  'act',
#  'blame',
#  'past',
#  '6',
#  'trans',
#  'side',
#  'class',
#  'guns',
#  'non',
#  'likely',
#  'nice',
#  'anti',
#  'sick',
#  'heard',
#  'guys',
#  'seem',
#  'line',
#  'unless',
#  'pain',
#  'democrats',
#  '*',
#  'given',
#  'drug',
#  'learn',
#  'john',
#  'funny',
#  'allowed',
#  'words',
#  'correct',
#  'obviously',
#  'respect',
#  'especially',
#  'common',
#  'knew',
#  'difference',
#  'stay',
#  'watch',
#  'million',
#  'wonder',
#  'almost',
#  'paid',
#  'die',
#  'marriage',
#  'boy',
#  'mom',
#  'friends',
#  'simple',
#  'music',
#  'problems',
#  'small',
#  'college',
#  'girls',
#  'buy',
#  'married',
#  'community',
#  'during',
#  'gop',
#  'son',
#  'wait',
#  'gender',
#  'legal',
#  'brain',
#  'coming',
#  'started',
#  'alone',
#  'reality',
#  'single',
#  'realize',
#  'thank',
#  'father',
#  'behind',
#  'sounds',
#  'attention',
#  'animals',
#  'evidence',
#  'social',
#  'turn',
#  'moron',
#  'stuff',
#  'service',
#  'wow',
#  'idiots',
#  'play',
#  'normal',
#  'husband',
#  'win',
#  'stand',
#  'top',
#  'open',
#  'completely',
#  'second',
#  'nation',
#  'hey',
#  'taken',
#  'thanks',
#  'entire',
#  'happy',
#  'friend',
#  'office',
#  'population',
#  'died',
#  'created',
#  'order',
#  'bet',
#  'force',
#  'worse',
#  'eat',
#  'low',
#  'gave',
#  'absolutely',
#  'middle',
#  'number',
#  'education',
#  'due',
#  'shows',
#  'happens',
#  'hand',
#  'climate',
#  'answer',
#  'along',
#  'example',
#  'natural',
#  'church',
#  'straight',
#  'half',
#  'continue',
#  'speak',
#  'taxes',
#  'restroom',
#  'couple',
#  'bernie',
#  'lgbt',
#  'nobody',
#  'shot',
#  'bring',
#  'mental',
#  'donald',
#  'bush',
#  'none',
#  'millions',
#  'check',
#  'together',
#  'move',
#  'longer',
#  'saw',
#  'choose',
#  'claim',
#  'lie',
#  'personal',
#  'possible',
#  'himself',
#  'type',
#  'behavior',
#  'hair',
#  'freedom',
#  'clearly',
#  'wish',
#  'situation',
#  'asked',
#  'sound',
#  'bit',
#  'dumb',
#  'easy',
#  'close',
#  'known',
#  'running',
#  'needed',
#  'voting',
#  'private',
#  'special',
#  'fine',
#  'important',
#  'book',
#  'rich',
#  'quite',
#  'except',
#  'paying',
#  'set',
#  'experience',
#  'countries',
#  'whether',
#  'gone',
#  'totally',
#  'judge',
#  'chance',
#  'beliefs',
#  'perhaps',
#  'kasich',
#  'seriously',
#  'sanders',
#  'fear',
#  'calling',
#  'truly',
#  'hit',
#  'often',
#  'criminal',
#  'planet',
#  'three',
#  'nor',
#  'general',
#  'lose',
#  'tried',
#  'takes',
#  'company',
#  'telling',
#  'murder',
#  'follow',
#  'myself',
#  'muslims',
#  'conservative',
#  'democrat',
#  'killing',
#  'citizens',
#  'months',
#  'election',
#  'doubt',
#  'explain',
#  'reading',
#  'u.s.',
#  'huge',
#  'color',
#  'birth',
#  'allow',
#  'rape',
#  'cops',
#  'slavery',
#  'china',
#  'cost',
#  'evil',
#  'certain',
#  'humans',
#  'accept',
#  'health',
#  'thinks',
#  'oil',
#  'lying',
#  'worked',
#  'boys',
#  'later',
#  'medical',
#  'gays',
#  'heart',
#  'rules',
#  'research',
#  'works',
#  'doctor',
#  'level',
#  'exist',
#  'm',
#  'several',
#  'including',
#  'south',
#  'military',
#  'cut',
#  'north',
#  'politicians',
#  'teacher',
#  'soon',
#  'lack',
#  'certainly',
#  'giving',
#  'sin',
#  'beautiful',
#  'information',
#  'statement',
#  'higher',
#  'future',
#  'anymore',
#  'anyway',
#  'ignorance',
#  'argument',
#  'tv',
#  'fight',
#  'form',
#  'speech',
#  'prove',
#  'shut',
#  'lies',
#  'term',
#  'voters',
#  'skin',
#  'u',
#  'candidate',
#  'expect',
#  'forget',
#  'internet',
#  'forced',
#  'protect',
#  'discrimination',
#  'lady',
#  'grow',
#  'above',
#  'cares',
#  'economy',
#  'imagine',
#  'bs',
#  'supposed',
#  'smart',
#  'companies',
#  'period',
#  'court',
#  'palin',
#  'night',
#  'bunch',
#  'according',
#  'rate',
#  'city',
#  'usa',
#  'national',
#  'large',
#  'proof',
#  'debt',
#  'abuse',
#  'front',
#  'dress',
#  'welfare',
#  'responsible',
#  'hold',
#  'walk',
#  'civil',
#  'rock',
#  'save',
#  'usually',
#  'michael',
#  'attack',
#  'dog',
#  'phone',
#  'mention',
#  'bathrooms',
#  'jail',
#  'prison',
#  'equal',
#  'african',
#  'victim',
#  'joke',
#  'land',
#  'clear',
#  'actual',
#  'cop',
#  'pass',
#  'dollars',
#  'fire',
#  'supporters',
#  'fat',
#  'mouth',
#  'thousands',
#  'written',
#  'violence',
#  'involved',
#  'video',
#  'hurt',
#  'fault',
#  'muslim',
#  'list',
#  'slaves',
#  'disgusting',
#  'stories',
#  'worth',
#  'fun',
#  'groups',
#  'global',
#  'crazy',
#  'sell',
#  'actions',
#  'hands',
#  'worst',
#  'safe',
#  'united',
#  'sometimes',
#  'student',
#  'faith',
#  'outside',
#  'week',
#  'consider',
#  'changed',
#  'excuse',
#  'wall',
#  'dad',
#  'safety',
#  'doctors',
#  'herself',
#  'average',
#  'ways',
#  'schools',
#  'total',
#  'lead',
#  'finally',
#  'beat',
#  'federal',
#  'culture',
#  'per',
#  'apparently',
#  'violent',
#  'banks',
#  'agenda',
#  'ridiculous',
#  'upon',
#  'campaign',
#  'seeing',
#  'tired',
#  'theory',
#  'month',
#  'within',
#  'okay',
#  'dangerous',
#  'relationship',
#  'short',
#  'students',
#  'perfect',
#  'amount',
#  'interest',
#  'intelligent',
#  'pick',
#  'crimes',
#  '00,000',
#  'door',
#  'spend',
#  'area',
#  'figure',
#  'write',
#  'brought',
#  '7',
#  'early',
#  'trust',
#  'hours',
#  'lived',
#  'breast',
#  'nature',
#  'street',
#  'babies',
#  'putting',
#  'fool',
#  'congress',
#  'teeth',
#  'pathetic',
#  'fast',
#  'personally',
#  'regardless',
#  'break',
#  'light',
#  '0.0',
#  'plus',
#  'game',
#  'major',
#  'scientists',
#  'logic',
#  'glad',
#  'picture',
#  'otherwise',
#  'tip',
#  'gas',
#  'elected',
#  'educated',
#  'listen',
#  'current',
#  'movie',
#  'treated',
#  'shoot',
#  'christ',
#  'obvious',
#  'create',
#  'english',
#  'older',
#  'late',
#  'constitution',
#  'illegals',
#  'damn',
#  'racial',
#  'animal',
#  'beyond',
#  'taught',
#  'flag',
#  'zero',
#  'definitely',
#  'reasons',
#  'view',
#  'watching',
#  'biggest',
#  'market',
#  'minority',
#  'shame',
#  'parent',
#  'considered',
#  'families',
#  'record',
#  'fall',
#  'fake',
#  'lifestyle',
#  'turned',
#  'conservatives',
#  'pregnant',
#  'interesting',
#  'complete',
#  'members',
#  'caused',
#  'wear',
#  'ladies',
#  'loved',
#  'security',
#  'drive',
#  'blood',
#  'plenty',
#  'adult',
#  'o',
#  'passed',
#  ...]

# %%
# the number comes from the number of repetition
vocab = Vocab(itos_new)
if not cut is None:
    data_lm = TextLMDataBunch.from_df(EX_PA, df_lm_train, df_lm_val, vocab=vocab, text_cols='text_proc', tokenizer=Tokenizer(cut_n_from_behind=cut))
else:
    data_lm = TextLMDataBunch.from_df(EX_PA, df_lm_train, df_lm_val, vocab=vocab, text_cols='text_proc')
data_lm.save()
